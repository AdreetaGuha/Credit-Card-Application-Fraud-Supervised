# %%
from timeit import default_timer as timer
import pandas as pd
import scipy.stats
import numpy as np
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
start_time = timer()

# %%
data = pd.read_csv('applications data.csv')

# %%
data.shape
# Out:
# (1000000, 10)

# %%
data.head(10)
# Out:
#    record      date        ssn  firstname  lastname        address   zip5  \
# 0       1  20160101  379070012   XRRAMMTR  SMJETJMJ  6861 EUTST PL   2765
# 1       2  20160101  387482503   MAMSTUJR  RTTEMRRR  7280 URASA PL  57169
# 2       3  20160101  200332444  SZMMUJEZS  EUSEZRAE  5581 RSREX LN  56721
# 3       4  20160101  747451317  SJJZSXRSZ  ETJXTXXS  1387 UJZXJ RD  35286
# 4       5  20160101   24065868  SSSXUEJMS  SSUUJXUZ   279 EAASA WY   3173
# 5       6  20160101  922264214  XEEJJSTER   ERJSAXA  4322 USJXU LN   8391
# 6       7  20160101  415812149  XZJRJUSRR  STSMJRUM   478 EEXUM LN  41640
# 7       8  20160101  373752050  EJMRRSUXR   AMTZXRU   8906 UUAJ PL  60567
# 8       9  20160101  769970791  RXTSZJATS  RSXMRJME  8266 SSEAR RD  37934
# 9      10  20160101  732119085  EREMTZXXA  EXMMSEXT  9166 XXSAZ PL  93751
#
#         dob   homephone  fraud_label
# 0  19070626  1797504115            0
# 1  19340615  4164239415            1
# 2  19070626   216537580            0
# 3  19440430   132144161            0
# 4  19980315  6101082272            0
# 5  19480613  5742016319            0
# 6  19640318  7697396312            0
# 7  19190528  2727421586            0
# 8  19900314  5520652307            0
# 9  19750127  3749451123            0

# %%
data.dtypes
# Out:
# record          int64
# date            int64
# ssn             int64
# firstname      object
# lastname       object
# address        object
# zip5            int64
# dob             int64
# homephone       int64
# fraud_label     int64
# dtype: object

# %%
data['appyear'] = (data['date'] / 10000).astype('int')
data['appmonth'] = ((data['date'] - data['appyear'] * 10000) / 100).astype('int')
data['appday'] = data['date'] - data['appyear'] * 10000 - data['appmonth'] * 100
data['date'] = pd.to_datetime(data.appyear*10000+data.appmonth*100+data.appday,format='%Y%m%d')
data = data.drop(columns = ['appyear','appmonth','appday'])

# %%
data.dtypes
# Out:
# record                  int64
# date           datetime64[ns]
# ssn                     int64
# firstname              object
# lastname               object
# address                object
# zip5                    int64
# dob                     int64
# homephone               int64
# fraud_label             int64
# dtype: object

# %%
data.head(5)
# Out:
#    record       date        ssn  firstname  lastname        address   zip5  \
# 0       1 2016-01-01  379070012   XRRAMMTR  SMJETJMJ  6861 EUTST PL   2765
# 1       2 2016-01-01  387482503   MAMSTUJR  RTTEMRRR  7280 URASA PL  57169
# 2       3 2016-01-01  200332444  SZMMUJEZS  EUSEZRAE  5581 RSREX LN  56721
# 3       4 2016-01-01  747451317  SJJZSXRSZ  ETJXTXXS  1387 UJZXJ RD  35286
# 4       5 2016-01-01   24065868  SSSXUEJMS  SSUUJXUZ   279 EAASA WY   3173
#
#         dob   homephone  fraud_label
# 0  19070626  1797504115            0
# 1  19340615  4164239415            1
# 2  19070626   216537580            0
# 3  19440430   132144161            0
# 4  19980315  6101082272            0

# %%
data.tail(5)
# Out:
#          record       date        ssn  firstname  lastname         address  \
# 999995   999996 2016-12-31  766104848  XUSAAURMZ  EJXXEXZX  8079 EJRUJ AVE
# 999996   999997 2016-12-31  445178058  SAAJJEMTX  UMAUETJX  4817 UMSXT AVE
# 999997   999998 2016-12-31   25283410  ESRXXRSUX  EUEJRJJE   7562 RJMAZ ST
# 999998   999999 2016-12-31  361232148  XXMZSRXMA  RSRSUJSS   3408 UZZAM WY
# 999999  1000000 2016-12-31   40027083  RXZXSMEZA  UTEAAZXU    112 UTTJT PL
#
#          zip5       dob   homephone  fraud_label
# 999995  54890  19550418  8236558223            0
# 999996  74683  19150624  6790134432            0
# 999997  86805  19880628  3997657622            0
# 999998  49183  20120302  5935293731            0
# 999999  39491  19820826  5869926905            0

# %%
data.describe()
# Out:
#                record           ssn            zip5           dob  \
# count  1000000.000000  1.000000e+06  1000000.000000  1.000000e+06
# mean    500000.500000  5.083415e+08    50073.333143  1.951725e+07
# std     288675.278933  2.934864e+08    28915.921546  3.568872e+05
# min          1.000000  3.600000e+01        2.000000  1.900010e+07
# 25%     250000.750000  2.542176e+08    24992.000000  1.916092e+07
# 50%     500000.500000  5.088144e+08    50492.000000  1.950090e+07
# 75%     750000.250000  7.630924e+08    74496.000000  1.983032e+07
# max    1000000.000000  1.000000e+09    99999.000000  2.016103e+07
#
#           homephone     fraud_label
# count  1.000000e+06  1000000.000000
# mean   5.368716e+09        0.014393
# std    3.082161e+09        0.119104
# min    5.937990e+05        0.000000
# 25%    2.677134e+09        0.000000
# 50%    5.399910e+09        0.000000
# 75%    8.109241e+09        0.000000
# max    1.000000e+10        1.000000

# %%
data.count()
# Out:
# record         1000000
# date           1000000
# ssn            1000000
# firstname      1000000
# lastname       1000000
# address        1000000
# zip5           1000000
# dob            1000000
# homephone      1000000
# fraud_label    1000000
# dtype: int64

# %%
data['fraud_label'].sum()
# Out:
# 14393

# %%
print(len(data[data['fraud_label'] == 0]))
# Out:
# 985607

# %%
print(len(data[data['fraud_label'] == 0]) + len(data[data['fraud_label'] != 0]))
# Out:
# 1000000

# %%
goods = data[data['fraud_label'] == 0]
bads = data[data['fraud_label'] == 1]

# %%
numrecords = len(data)
print(numrecords)
# Out:
# 1000000

# %%
print(len(goods))
# Out:
# 985607

# %%
print(len(bads))
# Out:
# 14393

# %%
len(data['record'].unique())
# Out:
# 1000000

# %%
len(data['record']) * 100 / numrecords
# Out:
# 100.0

# %%
len(data['date']) * 100 / numrecords
# Out:
# 100.0

# %%
len(data['date'].unique())
# Out:
# 365

# %%
count_day = data.groupby('date').count()
count_day.head(10)
# Out:
#             record   ssn  firstname  lastname  address  zip5   dob  homephone  \
# date
# 2016-01-01    2840  2840       2840      2840     2840  2840  2840       2840
# 2016-01-02    2719  2719       2719      2719     2719  2719  2719       2719
# 2016-01-03    2764  2764       2764      2764     2764  2764  2764       2764
# 2016-01-04    2757  2757       2757      2757     2757  2757  2757       2757
# 2016-01-05    2732  2732       2732      2732     2732  2732  2732       2732
# 2016-01-06    2682  2682       2682      2682     2682  2682  2682       2682
# 2016-01-07    2782  2782       2782      2782     2782  2782  2782       2782
# 2016-01-08    2809  2809       2809      2809     2809  2809  2809       2809
# 2016-01-09    2779  2779       2779      2779     2779  2779  2779       2779
# 2016-01-10    2758  2758       2758      2758     2758  2758  2758       2758
#
#             fraud_label
# date
# 2016-01-01         2840
# 2016-01-02         2719
# 2016-01-03         2764
# 2016-01-04         2757
# 2016-01-05         2732
# 2016-01-06         2682
# 2016-01-07         2782
# 2016-01-08         2809
# 2016-01-09         2779
# 2016-01-10         2758

# %%
daily_count = data.assign(apps = np.ones(numrecords)).set_index(data['date']).resample(dt.timedelta(days = 1))\
    .count().apps
daily_count.plot(title = 'Daily Applications')
# Out:
# <AxesSubplot:title={'center':'Daily Applications'}, xlabel='date'>

# %%
daily_count = data.assign(apps = np.ones(numrecords)).set_index(data['date']).resample(dt.timedelta(days = 1))\
    .count().apps
plt.ylim(2500,3000)
daily_count.plot(title = 'Daily Applications')
# Out:
# <AxesSubplot:title={'center':'Daily Applications'}, xlabel='date'>

# %%
daily_count.head(70)
# Out:
# date
# 2016-01-01    2840
# 2016-01-02    2719
# 2016-01-03    2764
# 2016-01-04    2757
# 2016-01-05    2732
#               ...
# 2016-03-06    2730
# 2016-03-07    2831
# 2016-03-08    2798
# 2016-03-09    2738
# 2016-03-10    2643
# Freq: D, Name: apps, Length: 70, dtype: int64

# %%
daily_count['2016-02-29'] = daily_count['2016-02-28']
daily_count.head(70)
# Out:
# date
# 2016-01-01    2840
# 2016-01-02    2719
# 2016-01-03    2764
# 2016-01-04    2757
# 2016-01-05    2732
#               ...
# 2016-03-06    2730
# 2016-03-07    2831
# 2016-03-08    2798
# 2016-03-09    2738
# 2016-03-10    2643
# Freq: D, Name: apps, Length: 70, dtype: int64

# %%
daily_count.plot(title = 'Daily Applications')
# Out:
# <AxesSubplot:title={'center':'Daily Applications'}, xlabel='date'>

# %%
ngoods = len(goods)
nbads = len(bads)
goods_series = goods.assign(apps = np.ones(ngoods)).set_index(goods['date']).resample(dt.timedelta(days = 1)).count().apps
norm_goods_series = goods_series / ngoods
norm_goods_series.plot(title = 'Daily Applicationss', color = 'green')
bads_series = bads.assign(apps = np.ones(nbads)).set_index(bads['date']).resample(dt.timedelta(days = 1)).count().apps
norm_bads_series = bads_series / nbads
norm_bads_series.plot(color = 'red')
# Out:
# <AxesSubplot:title={'center':'Daily Applicationss'}, xlabel='date'>

# %%
weekly_applications = data.assign(apps = np.ones(numrecords)).set_index(data['date']).resample(dt.timedelta(days = 7))\
    .count().apps
weekly_applications.plot(title = 'Weekly Applications')
# Out:
# <AxesSubplot:title={'center':'Weekly Applications'}, xlabel='date'>

# %%
weekly_applications.head(60)
# Out:
# date
# 2016-01-01    19276
# 2016-01-08    19235
# 2016-01-15    19272
# 2016-01-22    19068
# 2016-01-29    19363
# 2016-02-05    19318
# 2016-02-12    19081
# 2016-02-19    19067
# 2016-02-26    16531
# 2016-03-04    19323
# 2016-03-11    19029
# 2016-03-18    19118
# 2016-03-25    19181
# 2016-04-01    19306
# 2016-04-08    19052
# 2016-04-15    19508
# 2016-04-22    19254
# 2016-04-29    19217
# 2016-05-06    19284
# 2016-05-13    19143
# 2016-05-20    19204
# 2016-05-27    19057
# 2016-06-03    19463
# 2016-06-10    19000
# 2016-06-17    19151
# 2016-06-24    18994
# 2016-07-01    18950
# 2016-07-08    19160
# 2016-07-15    19351
# 2016-07-22    19255
# 2016-07-29    19233
# 2016-08-05    19108
# 2016-08-12    19258
# 2016-08-19    19116
# 2016-08-26    19080
# 2016-09-02    19362
# 2016-09-09    19082
# 2016-09-16    19169
# 2016-09-23    19292
# 2016-09-30    19272
# 2016-10-07    19067
# 2016-10-14    19160
# 2016-10-21    19227
# 2016-10-28    19080
# 2016-11-04    18896
# 2016-11-11    18975
# 2016-11-18    19084
# 2016-11-25    19196
# 2016-12-02    19247
# 2016-12-09    19147
# 2016-12-16    18986
# 2016-12-23    19254
# 2016-12-30     5498
# Freq: 7D, Name: apps, dtype: int64

# %%
weekly_applications['2016-02-26'] = weekly_applications['2016-02-19']
weekly_applications['2016-12-30'] = weekly_applications['2016-12-23']
weekly_applications.plot(title = 'Weekly Applications')
# Out:
# <AxesSubplot:title={'center':'Weekly Applications'}, xlabel='date'>

# %%
goods_series = goods.assign(apps = np.ones(ngoods)).set_index(goods['date']).resample(dt.timedelta(days = 7)).count().apps
norm_goods_series = goods_series / ngoods
norm_goods_series.plot(title = 'Weeky Applications', color = 'green')
bads_series = bads.assign(apps = np.ones(nbads)).set_index(bads['date']).resample(dt.timedelta(days = 7)).count().apps
norm_bads_series = bads_series / nbads
norm_bads_series.plot(color = 'red')
# Out:
# <AxesSubplot:title={'center':'Weeky Applications'}, xlabel='date'>

# %%
len(data['ssn']) * 100 / numrecords
# Out:
# 100.0

# %%
len(data['ssn'].unique())
# Out:
# 835819

# %%
data['ssn'].value_counts()
# Out:
# 999999999    16935
# 938972725      114
# 810776805       81
# 829352390       74
# 473311863       44
#              ...
# 571979227        1
# 154696808        1
# 962389432        1
# 746697518        1
# 361232148        1
# Name: ssn, Length: 835819, dtype: int64

# %%
sns.set(font_scale=1.5)
data['ssn'].value_counts().head(15).plot(kind = 'bar')
plt.yscale('log')

# %%
data[data['ssn'] == 999999999].head(20)
# Out:
#       record       date        ssn  firstname  lastname          address  \
# 10        11 2016-01-01  999999999  UZZSMXSEE   USJZUSA     726 UMTXU ST
# 22        23 2016-01-01  999999999  ETXMUSZEM   UJMAMEU    3387 STRUM WY
# 64        65 2016-01-01  999999999  STUMMAMTS  SSJXTUJM    6393 UEJEA LN
# 68        69 2016-01-01  999999999  UUZAJXZMT  SRAAMZXU    2557 URRXS DR
# 74        75 2016-01-01  999999999   AUATMMZX   UUUTAZR      30 ETXRM ST
# 283      284 2016-01-01  999999999  MSJUZSMZJ  UXMTEZUT    356 UZSRE AVE
# 380      381 2016-01-01  999999999  XRJSMRRRT   RMRXAMX    9769 UAMZJ DR
# 420      421 2016-01-01  999999999  XRXMTMZEZ  SZRXXJMX    5854 RXRXX PL
# 446      447 2016-01-01  999999999   RRZUZUSX  ESZRRRAA     8970 AXME RD
# 468      469 2016-01-01  999999999  XETRJXESR  SSJXTUJM    6995 RMSST CT
# 520      521 2016-01-01  999999999  RTMMTSZRZ   MEAXJUX   8778 EMUEX AVE
# 607      608 2016-01-01  999999999  RTEAZZJJZ  USMATTUR    2370 EAJEZ RD
# 651      652 2016-01-01  999999999  REUJAUMUT  RATZUERE    7717 XRRXE DR
# 788      789 2016-01-01  999999999  EMMUZZEEZ  UZSEMAZJ    5370 SUTSR ST
# 899      900 2016-01-01  999999999  EASEXMJAT  UJUMXTZM      2007 MEM PL
# 907      908 2016-01-01  999999999  UXJXSXURA  RRARMXRX  4369 SZSAE BLVD
# 958      959 2016-01-01  999999999  XAREUJZUM  RTSUXJST     4265 EUSX ST
# 1000    1001 2016-01-01  999999999  ERXTXXZEX   XATTMRZ    5372 RXZTT DR
# 1032    1033 2016-01-01  999999999  XXXZMSJMU  RTESSAXZ    2066 EZMZJ LN
# 1105    1106 2016-01-01  999999999  XXUMRXASU  STJRSZRZ   6848 SAJSM AVE
#
#        zip5       dob   homephone  fraud_label
# 10    92129  19400126  3026547212            0
# 22    45982  19580830  5568704443            0
# 64    41640  19070626  9999999999            0
# 68    98407  20110831  5490098836            0
# 74    38402  19760625  2382673773            0
# 283   74187  19070626   153492955            0
# 380   52351  19070626  3181686949            0
# 420   34957  19970721   316681200            0
# 446   48333  19110729  5350782211            0
# 468   48162  19700418  2503172355            0
# 520   15972  19070626  9999999999            0
# 607   31476  20110109  9289374745            0
# 651   85203  19070626  5962238641            0
# 788   45405  20060516  9999999999            0
# 899   52317  19000804  3301371772            0
# 907   91060  20070105  9999999999            0
# 958    1804  19521002  3304391399            0
# 1000  81912  20110604  4705993465            0
# 1032  42979  19461025  2617622312            0
# 1105   4400  20100209  5603700004            0

# %%
len(data['firstname']) * 100 / numrecords
# Out:
# 100.0

# %%
len(data['firstname'].unique())
# Out:
# 78136

# %%
data['firstname'].value_counts()
# Out:
# EAMSTRMT     12658
# TXEMXZZM     10297
# UXXJJZTUZ    10235
# UJSRSMUEZ     9994
# SREZUJMJU     9688
#              ...
# TUSSMZJA         1
# SSAZJXSRM        1
# UATETTATJ        1
# UASJMZXZJ        1
# RUZUJJRMX        1
# Name: firstname, Length: 78136, dtype: int64

# %%
data['firstname'].value_counts().head(15).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
len(data['lastname']) * 100 / numrecords
# Out:
# 100.0

# %%
len(data['lastname'].unique())
# Out:
# 177001

# %%
data['lastname'].value_counts()
# Out:
# ERJSAXA     8580
# UMXUUUSE    7156
# UMARRMA     6832
# MEAXJUX     5492
# XMERRR      5451
#             ...
# RMJZJRMJ       1
# SSUTSMUM       1
# EXASZEXS       1
# UERZXTTR       1
# RMJZURRS       1
# Name: lastname, Length: 177001, dtype: int64

# %%
data['lastname'].value_counts().head(15).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
len(data['address']) * 100 / numrecords
# Out:
# 100.0

# %%
len(data['address'].unique())
# Out:
# 828774

# %%
data['address'].value_counts()
# Out:
# 123 MAIN ST        1079
# 1775 XJXE LN         97
# 7433 RAEZA ST        80
# 8911 MZSU DR         74
# 4907 RRAAU DR        73
#                    ...
# 1179 RATUS BLVD       1
# 8006 SSRJM ST         1
# 6327 MAXR ST          1
# 4937 ESAMR LN         1
# 3408 UZZAM WY         1
# Name: address, Length: 828774, dtype: int64

# %%
data['address'].value_counts().head(15).plot(kind='bar',logy=True)
# Out:
# <AxesSubplot:>

# %%
data[data['address'] == '123 MAIN ST'].head(20)
# Out:
#        record       date        ssn  firstname  lastname      address   zip5  \
# 1247     1248 2016-01-01  904524264  UJSRSMUEZ  EAXAXAXA  123 MAIN ST  68138
# 2191     2192 2016-01-01  345413970  XXSMUSEJT  SRRAXESJ  123 MAIN ST  68138
# 2529     2530 2016-01-01  821839005  UXZUMTRTR  EARTMRJS  123 MAIN ST  68138
# 3434     3435 2016-01-02   24205988  SXTUZZXAS   UJJAJMM  123 MAIN ST  68138
# 3750     3751 2016-01-02  623763056  SEZESJMSR  UZJEUZMT  123 MAIN ST  68138
# 4715     4716 2016-01-02  686787130   SXXSZJMM   ARRZTAA  123 MAIN ST  68138
# 5353     5354 2016-01-02  932938215   UXRJESTM   EETAEAR  123 MAIN ST  68138
# 7299     7300 2016-01-03  417080344  SJETUJAAZ  REMJTREU  123 MAIN ST  92821
# 8512     8513 2016-01-04  477797652   EAMSTRMT  UTXXZZET  123 MAIN ST  68138
# 8750     8751 2016-01-04    6367698  XUERJXSTU  EERMEXAE  123 MAIN ST  42035
# 9051     9052 2016-01-04  268297199  XUERJXSTU  RUSXSMTS  123 MAIN ST  55457
# 9147     9148 2016-01-04  875566268  MJJJZUZTE   AJUZMTM  123 MAIN ST  68138
# 10043   10044 2016-01-04  828973613  USSZMRERM   TSUEEET  123 MAIN ST  68138
# 10588   10589 2016-01-04  999999999  RATREMERM  RJURSTXJ  123 MAIN ST  68138
# 10701   10702 2016-01-04  691187893  SRRZEXETU   UUTJTJM  123 MAIN ST  68138
# 10802   10803 2016-01-04  647675920  SJUXSATRM   XJMJMRA  123 MAIN ST  66279
# 13663   13664 2016-01-05  786557432  XRUURASXU  SAZMRUAA  123 MAIN ST  49706
# 14082   14083 2016-01-06  426706700   XTTTEXZA  UTAMRJSA  123 MAIN ST  68138
# 14257   14258 2016-01-06  738979458  SRTXJZSXM   EERMERJ  123 MAIN ST  97302
# 14789   14790 2016-01-06  746042136  STJZXXMET  RJSTUESS  123 MAIN ST  68138
#
#             dob   homephone  fraud_label
# 1247   19241031  8135264540            0
# 2191   19300526    94097353            0
# 2529   19621101  7715547340            0
# 3434   19640428  8788942828            0
# 3750   19731107   974228226            0
# 4715   19810323  1839236819            1
# 5353   19980513  5441682419            0
# 7299   19340914  7507186577            0
# 8512   19190519  5922864904            0
# 8750   19821127  6442565981            0
# 9051   19430413  4330604659            0
# 9147   19011214  9999999999            0
# 10043  19040413  1886028283            0
# 10588  20020214  9999999999            0
# 10701  19030505  3092099983            0
# 10802  19000124  1932109910            0
# 13663  20141210  7078543383            0
# 14082  19461231  2890618122            0
# 14257  20001128  2232057333            0
# 14789  20110806  8658354142            0

# %%
len(data['zip5']) * 100 / numrecords
# Out:
# 100.0

# %%
len(data['zip5'].unique())
# Out:
# 26370

# %%
data['zip5'].value_counts()
# Out:
# 68138    823
# 90042    514
# 89835    489
# 35227    478
# 14931    459
#         ...
# 1599       1
# 69474      1
# 51017      1
# 25995      1
# 21226      1
# Name: zip5, Length: 26370, dtype: int64

# %%
data['zip5'].value_counts().head(20).plot(kind='bar',logy=True)
# Out:
# <AxesSubplot:>

# %%
len(data['dob']) * 100 / numrecords
# Out:
# 100.0

# %%
len(data['dob'].unique())
# Out:
# 42673

# %%
data['dob'].value_counts()
# Out:
# 19070626    126568
# 19640318      4818
# 19760625      3723
# 19880628      1404
# 19740216       980
#              ...
# 19280730         5
# 19860313         5
# 19190223         5
# 19441127         5
# 19960904         5
# Name: dob, Length: 42673, dtype: int64

# %%
data['dob'].value_counts().head(15).plot(kind='bar',logy=True)
# Out:
# <AxesSubplot:>

# %%
len(data['homephone']) * 100 / numrecords
# Out:
# 100.0

# %%
len(data['homephone'].unique())
# Out:
# 28244

# %%
data['homephone'].value_counts()
# Out:
# 9999999999    78512
# 6384782007      466
# 6035129044      360
# 2113738531      331
# 4024680535      198
#               ...
# 3450484388        1
# 5376503138        1
# 7106175831        1
# 5010200060        1
# 6271618925        1
# Name: homephone, Length: 28244, dtype: int64

# %%
data['homephone'].value_counts().head(15).plot(kind='bar',logy=True)
# Out:
# <AxesSubplot:>

# %%
data[data['homephone'] == 9999999999].head(10)
# Out:
#      record       date        ssn  firstname  lastname          address  \
# 17       18 2016-01-01  346374636  XRSSZZUXT  ETXZXJAJ    5719 UEZJT PL
# 26       27 2016-01-01  735495403  EMSSTSXUA  STZRUXZM    9323 STRMS PL
# 60       61 2016-01-01  780136117   UZTZEETU   ARUZTZM    5317 UTXME ST
# 64       65 2016-01-01  999999999  STUMMAMTS  SSJXTUJM    6393 UEJEA LN
# 145     146 2016-01-01  671506143   TXEMXZZM  SRTERSRA  5795 UMUTM BLVD
# 149     150 2016-01-01  149112205  EZTERXZRA  EERMAXJU     2249 XXAU DR
# 178     179 2016-01-01  507916615  EUEJUURAR   XUSMXRU     8314 XXMX DR
# 179     180 2016-01-01  106080337  SRARXRMRM  UTJMRJUX    8413 URUEU WY
# 180     181 2016-01-01  291680381  MUSXJTSSX   EXAAJUT    9762 SXJXM LN
# 200     201 2016-01-01   13382014   EAMSTRMT  RURSXSXX     372 SXTEA DR
#
#       zip5       dob   homephone  fraud_label
# 17   51486  19500110  9999999999            0
# 26   51395  19881111  9999999999            0
# 60   37840  19731129  9999999999            0
# 64   41640  19070626  9999999999            0
# 145  45077  19030913  9999999999            0
# 149  27375  19841206  9999999999            0
# 178    398  19720416  9999999999            0
# 179  15746  19070626  9999999999            0
# 180  41694  19620504  9999999999            0
# 200  42716  19070626  9999999999            0

# %%
print(f'Duration: {(timer() - start_time) / 60: 0.2f} minutes, or{(timer() - start_time): 0.0f} seconds')
# Out:
# Duration:  0.35 minutes, or 21 seconds

# %%
data
# Out:
#          record       date        ssn  firstname  lastname         address  \
# 0             1 2016-01-01  379070012   XRRAMMTR  SMJETJMJ   6861 EUTST PL
# 1             2 2016-01-01  387482503   MAMSTUJR  RTTEMRRR   7280 URASA PL
# 2             3 2016-01-01  200332444  SZMMUJEZS  EUSEZRAE   5581 RSREX LN
# 3             4 2016-01-01  747451317  SJJZSXRSZ  ETJXTXXS   1387 UJZXJ RD
# 4             5 2016-01-01   24065868  SSSXUEJMS  SSUUJXUZ    279 EAASA WY
# ...         ...        ...        ...        ...       ...             ...
# 999995   999996 2016-12-31  766104848  XUSAAURMZ  EJXXEXZX  8079 EJRUJ AVE
# 999996   999997 2016-12-31  445178058  SAAJJEMTX  UMAUETJX  4817 UMSXT AVE
# 999997   999998 2016-12-31   25283410  ESRXXRSUX  EUEJRJJE   7562 RJMAZ ST
# 999998   999999 2016-12-31  361232148  XXMZSRXMA  RSRSUJSS   3408 UZZAM WY
# 999999  1000000 2016-12-31   40027083  RXZXSMEZA  UTEAAZXU    112 UTTJT PL
#
#          zip5       dob   homephone  fraud_label
# 0        2765  19070626  1797504115            0
# 1       57169  19340615  4164239415            1
# 2       56721  19070626   216537580            0
# 3       35286  19440430   132144161            0
# 4        3173  19980315  6101082272            0
# ...       ...       ...         ...          ...
# 999995  54890  19550418  8236558223            0
# 999996  74683  19150624  6790134432            0
# 999997  86805  19880628  3997657622            0
# 999998  49183  20120302  5935293731            0
# 999999  39491  19820826  5869926905            0
#
# [1000000 rows x 10 columns]

# %%
data.dtypes
# Out:
# record                  int64
# date           datetime64[ns]
# ssn                     int64
# firstname              object
# lastname               object
# address                object
# zip5                    int64
# dob                     int64
# homephone               int64
# fraud_label             int64
# dtype: object

# %%
import datetime as dt
from datetime import datetime

# %%
#data['date'] = pd.to_datetime(data.date.astype(str).apply (lambda x:x[:4]+ '-' + x[4:6] +'-' + x[6:]))
data['zip5'] = data['zip5'].apply(lambda x: '{0:0>5}'.format(x))
data
# Out:
#          record       date        ssn  firstname  lastname         address  \
# 0             1 2016-01-01  379070012   XRRAMMTR  SMJETJMJ   6861 EUTST PL
# 1             2 2016-01-01  387482503   MAMSTUJR  RTTEMRRR   7280 URASA PL
# 2             3 2016-01-01  200332444  SZMMUJEZS  EUSEZRAE   5581 RSREX LN
# 3             4 2016-01-01  747451317  SJJZSXRSZ  ETJXTXXS   1387 UJZXJ RD
# 4             5 2016-01-01   24065868  SSSXUEJMS  SSUUJXUZ    279 EAASA WY
# ...         ...        ...        ...        ...       ...             ...
# 999995   999996 2016-12-31  766104848  XUSAAURMZ  EJXXEXZX  8079 EJRUJ AVE
# 999996   999997 2016-12-31  445178058  SAAJJEMTX  UMAUETJX  4817 UMSXT AVE
# 999997   999998 2016-12-31   25283410  ESRXXRSUX  EUEJRJJE   7562 RJMAZ ST
# 999998   999999 2016-12-31  361232148  XXMZSRXMA  RSRSUJSS   3408 UZZAM WY
# 999999  1000000 2016-12-31   40027083  RXZXSMEZA  UTEAAZXU    112 UTTJT PL
#
#          zip5       dob   homephone  fraud_label
# 0       02765  19070626  1797504115            0
# 1       57169  19340615  4164239415            1
# 2       56721  19070626   216537580            0
# 3       35286  19440430   132144161            0
# 4       03173  19980315  6101082272            0
# ...       ...       ...         ...          ...
# 999995  54890  19550418  8236558223            0
# 999996  74683  19150624  6790134432            0
# 999997  86805  19880628  3997657622            0
# 999998  49183  20120302  5935293731            0
# 999999  39491  19820826  5869926905            0
#
# [1000000 rows x 10 columns]

# %%
data.loc[data.ssn == 999999999, 'ssn'] = -data[data.ssn == 999999999]['record']
data['ssn'] = data['ssn'].apply(lambda x: '{0:0>9}'.format(x))
data
# Out:
#          record       date        ssn  firstname  lastname         address  \
# 0             1 2016-01-01  379070012   XRRAMMTR  SMJETJMJ   6861 EUTST PL
# 1             2 2016-01-01  387482503   MAMSTUJR  RTTEMRRR   7280 URASA PL
# 2             3 2016-01-01  200332444  SZMMUJEZS  EUSEZRAE   5581 RSREX LN
# 3             4 2016-01-01  747451317  SJJZSXRSZ  ETJXTXXS   1387 UJZXJ RD
# 4             5 2016-01-01  024065868  SSSXUEJMS  SSUUJXUZ    279 EAASA WY
# ...         ...        ...        ...        ...       ...             ...
# 999995   999996 2016-12-31  766104848  XUSAAURMZ  EJXXEXZX  8079 EJRUJ AVE
# 999996   999997 2016-12-31  445178058  SAAJJEMTX  UMAUETJX  4817 UMSXT AVE
# 999997   999998 2016-12-31  025283410  ESRXXRSUX  EUEJRJJE   7562 RJMAZ ST
# 999998   999999 2016-12-31  361232148  XXMZSRXMA  RSRSUJSS   3408 UZZAM WY
# 999999  1000000 2016-12-31  040027083  RXZXSMEZA  UTEAAZXU    112 UTTJT PL
#
#          zip5       dob   homephone  fraud_label
# 0       02765  19070626  1797504115            0
# 1       57169  19340615  4164239415            1
# 2       56721  19070626   216537580            0
# 3       35286  19440430   132144161            0
# 4       03173  19980315  6101082272            0
# ...       ...       ...         ...          ...
# 999995  54890  19550418  8236558223            0
# 999996  74683  19150624  6790134432            0
# 999997  86805  19880628  3997657622            0
# 999998  49183  20120302  5935293731            0
# 999999  39491  19820826  5869926905            0
#
# [1000000 rows x 10 columns]

# %%
data['address'] = np.where(data['address'] == "123 MAIN ST", -data['record'], data['address'])
data['address'] = data['address'].astype(str)

# %%
data.head(100)
# Out:
#     record       date        ssn  firstname  lastname        address   zip5  \
# 0        1 2016-01-01  379070012   XRRAMMTR  SMJETJMJ  6861 EUTST PL  02765
# 1        2 2016-01-01  387482503   MAMSTUJR  RTTEMRRR  7280 URASA PL  57169
# 2        3 2016-01-01  200332444  SZMMUJEZS  EUSEZRAE  5581 RSREX LN  56721
# 3        4 2016-01-01  747451317  SJJZSXRSZ  ETJXTXXS  1387 UJZXJ RD  35286
# 4        5 2016-01-01  024065868  SSSXUEJMS  SSUUJXUZ   279 EAASA WY  03173
# ..     ...        ...        ...        ...       ...            ...    ...
# 95      96 2016-01-01  939863686    UUZMJST  RJURSTXJ  7277 XEART CT  69109
# 96      97 2016-01-01  960805076  XRTAEZASZ  SUERZXAT  8411 URMMX RD  20001
# 97      98 2016-01-01  695355308   ZMEAJXJU   AXRTEJE  5743 RTRTX ST  25254
# 98      99 2016-01-01  870939019  ETREZZUXS  EAZSEEJE  200 UUUJM AVE  05507
# 99     100 2016-01-01  901665070  SZAEUEJUX  SZZRRXSE  6349 USUJT LN  83264
#
#          dob   homephone  fraud_label
# 0   19070626  1797504115            0
# 1   19340615  4164239415            1
# 2   19070626   216537580            0
# 3   19440430   132144161            0
# 4   19980315  6101082272            0
# ..       ...         ...          ...
# 95  19921029  7393643883            0
# 96  19950822  1458629808            0
# 97  19200526  5421614404            0
# 98  19770415  9419642060            0
# 99  19420104  8964364409            0
#
# [100 rows x 10 columns]

# %%
data.loc[data.dob == 19070626, 'dob'] = -data.loc[data.dob == 19070626]['record']
data['dob'] = data['dob'].apply(lambda x:'{0:0>8}'.format(x))
data
# Out:
#          record       date        ssn  firstname  lastname         address  \
# 0             1 2016-01-01  379070012   XRRAMMTR  SMJETJMJ   6861 EUTST PL
# 1             2 2016-01-01  387482503   MAMSTUJR  RTTEMRRR   7280 URASA PL
# 2             3 2016-01-01  200332444  SZMMUJEZS  EUSEZRAE   5581 RSREX LN
# 3             4 2016-01-01  747451317  SJJZSXRSZ  ETJXTXXS   1387 UJZXJ RD
# 4             5 2016-01-01  024065868  SSSXUEJMS  SSUUJXUZ    279 EAASA WY
# ...         ...        ...        ...        ...       ...             ...
# 999995   999996 2016-12-31  766104848  XUSAAURMZ  EJXXEXZX  8079 EJRUJ AVE
# 999996   999997 2016-12-31  445178058  SAAJJEMTX  UMAUETJX  4817 UMSXT AVE
# 999997   999998 2016-12-31  025283410  ESRXXRSUX  EUEJRJJE   7562 RJMAZ ST
# 999998   999999 2016-12-31  361232148  XXMZSRXMA  RSRSUJSS   3408 UZZAM WY
# 999999  1000000 2016-12-31  040027083  RXZXSMEZA  UTEAAZXU    112 UTTJT PL
#
#          zip5       dob   homephone  fraud_label
# 0       02765  000000-1  1797504115            0
# 1       57169  19340615  4164239415            1
# 2       56721  000000-3   216537580            0
# 3       35286  19440430   132144161            0
# 4       03173  19980315  6101082272            0
# ...       ...       ...         ...          ...
# 999995  54890  19550418  8236558223            0
# 999996  74683  19150624  6790134432            0
# 999997  86805  19880628  3997657622            0
# 999998  49183  20120302  5935293731            0
# 999999  39491  19820826  5869926905            0
#
# [1000000 rows x 10 columns]

# %%
data.loc[data.homephone == 9999999999, 'homephone'] = data.loc[data.homephone == 9999999999]['record']
data['homephone'] = data['homephone'].apply(lambda x: '{0:0>10}'.format(x))
data
# Out:
#          record       date        ssn  firstname  lastname         address  \
# 0             1 2016-01-01  379070012   XRRAMMTR  SMJETJMJ   6861 EUTST PL
# 1             2 2016-01-01  387482503   MAMSTUJR  RTTEMRRR   7280 URASA PL
# 2             3 2016-01-01  200332444  SZMMUJEZS  EUSEZRAE   5581 RSREX LN
# 3             4 2016-01-01  747451317  SJJZSXRSZ  ETJXTXXS   1387 UJZXJ RD
# 4             5 2016-01-01  024065868  SSSXUEJMS  SSUUJXUZ    279 EAASA WY
# ...         ...        ...        ...        ...       ...             ...
# 999995   999996 2016-12-31  766104848  XUSAAURMZ  EJXXEXZX  8079 EJRUJ AVE
# 999996   999997 2016-12-31  445178058  SAAJJEMTX  UMAUETJX  4817 UMSXT AVE
# 999997   999998 2016-12-31  025283410  ESRXXRSUX  EUEJRJJE   7562 RJMAZ ST
# 999998   999999 2016-12-31  361232148  XXMZSRXMA  RSRSUJSS   3408 UZZAM WY
# 999999  1000000 2016-12-31  040027083  RXZXSMEZA  UTEAAZXU    112 UTTJT PL
#
#          zip5       dob   homephone  fraud_label
# 0       02765  000000-1  1797504115            0
# 1       57169  19340615  4164239415            1
# 2       56721  000000-3  0216537580            0
# 3       35286  19440430  0132144161            0
# 4       03173  19980315  6101082272            0
# ...       ...       ...         ...          ...
# 999995  54890  19550418  8236558223            0
# 999996  74683  19150624  6790134432            0
# 999997  86805  19880628  3997657622            0
# 999998  49183  20120302  5935293731            0
# 999999  39491  19820826  5869926905            0
#
# [1000000 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 10 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   record       1000000 non-null  int64
#  1   date         1000000 non-null  datetime64[ns]
#  2   ssn          1000000 non-null  object
#  3   firstname    1000000 non-null  object
#  4   lastname     1000000 non-null  object
#  5   address      1000000 non-null  object
#  6   zip5         1000000 non-null  object
#  7   dob          1000000 non-null  object
#  8   homephone    1000000 non-null  object
#  9   fraud_label  1000000 non-null  int64
# dtypes: datetime64[ns](1), int64(2), object(7)
# memory usage: 76.3+ MB

# %% [markdown]
# # Day of week target encoding

# %%
import calendar
data['dow'] = data.date.apply(lambda x: calendar.day_name[x.weekday()])

# %%
train_test = data[data.date < '2016-11-01']

# %%
c = 4; nmid = 20; y_avg = train_test['fraud_label'].mean()
y_dow = train_test.groupby('dow')['fraud_label'].mean()
num = train_test.groupby('dow').size()
y_dow_smooth = y_avg + (y_dow - y_avg)/(1 + np.exp(-(num-nmid)/c))
data['dow_risk'] = data.dow.map(y_dow_smooth)

# %%
y_dow = y_dow.reset_index()
cats = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
y_dow['dow'] = pd.Categorical(y_dow['dow'], categories = cats, ordered = True)
y_dow = y_dow.sort_values('dow')
y_dow = y_dow.set_index('dow')

# %%
plt.style.use('ggplot')
fig, ax = plt.subplots(figsize = (20,10))
plt.bar(data = y_dow, x=y_dow.index, height = 'fraud_label', color = 'darkblue')
ax.set_ylim(bottom = 0.013)
ax.axhline(y = y_avg, ls = '--', lw = 2)

for i, v in enumerate(y_dow.index):
    ax.text(v, y_dow.loc[i, 'fraud_label'] + 0.0001, round(y_dow.loc[i, 'fraud_label'], 5), horizontalalignment = 'center', fontsize = 15)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15932/1835809367.py in <module>
#       6
#       7 for i, v in enumerate(y_dow.index):
# ----> 8     ax.text(v, y_dow.loc[i, 'fraud_label'] + 0.0001, round(y_dow.loc[i, 'fraud_label'], 5), horizontalalignment = 'center', fontsize = 15)
#       9
#      10 plt.show()
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1098     def _getitem_tuple(self, tup: tuple):
#    1099         with suppress(IndexingError):
# -> 1100             return self._getitem_lowerdim(tup)
#    1101
#    1102         # no multi-index, so validate all of the indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     836                 # We don't need to check for tuples here because those are
#     837                 #  caught by the _is_nested_tuple_indexer check above.
# --> 838                 section = self._getitem_axis(key, axis=i)
#     839
#     840                 # We should never have a scalar section here, because
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1162         # fall thru to straight lookup
#    1163         self._validate_key(key, axis)
# -> 1164         return self._get_label(key, axis=axis)
#    1165
#    1166     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1111     def _get_label(self, label, axis: int):
#    1112         # GH#5667 this will fail if the label is not present in the axis.
# -> 1113         return self.obj.xs(label, axis=axis)
#    1114
#    1115     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3774                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3775         else:
# -> 3776             loc = index.get_loc(key)
#    3777
#    3778             if isinstance(loc, np.ndarray):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3357                     "backfill or nearest lookups"
#    3358                 )
# -> 3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
#    3361                 return self._engine.get_loc(casted_key)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\category.py in _maybe_cast_indexer(self, key)
#     482         #  because this will correctly get partial-indexing on Interval categories
#     483         try:
# --> 484             return self._data._unbox_scalar(key)
#     485         except KeyError:
#     486             if is_valid_na_for_dtype(key, self.categories.dtype):
#
# ~\anaconda3\lib\site-packages\pandas\core\arrays\categorical.py in _unbox_scalar(self, key)
#    1869         # searchsorted is very performance sensitive. By converting codes
#    1870         # to same dtype as self.codes, we get much faster performance.
# -> 1871         code = self.categories.get_loc(key)
#    1872         code = self._ndarray.dtype.type(code)
#    1873         return code
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 0

# %%
data
# Out:
#          record       date        ssn  firstname  lastname         address  \
# 0             1 2016-01-01  379070012   XRRAMMTR  SMJETJMJ   6861 EUTST PL
# 1             2 2016-01-01  387482503   MAMSTUJR  RTTEMRRR   7280 URASA PL
# 2             3 2016-01-01  200332444  SZMMUJEZS  EUSEZRAE   5581 RSREX LN
# 3             4 2016-01-01  747451317  SJJZSXRSZ  ETJXTXXS   1387 UJZXJ RD
# 4             5 2016-01-01  024065868  SSSXUEJMS  SSUUJXUZ    279 EAASA WY
# ...         ...        ...        ...        ...       ...             ...
# 999995   999996 2016-12-31  766104848  XUSAAURMZ  EJXXEXZX  8079 EJRUJ AVE
# 999996   999997 2016-12-31  445178058  SAAJJEMTX  UMAUETJX  4817 UMSXT AVE
# 999997   999998 2016-12-31  025283410  ESRXXRSUX  EUEJRJJE   7562 RJMAZ ST
# 999998   999999 2016-12-31  361232148  XXMZSRXMA  RSRSUJSS   3408 UZZAM WY
# 999999  1000000 2016-12-31  040027083  RXZXSMEZA  UTEAAZXU    112 UTTJT PL
#
#          zip5       dob   homephone  fraud_label       dow  dow_risk
# 0       02765  000000-1  1797504115            0    Friday  0.014499
# 1       57169  19340615  4164239415            1    Friday  0.014499
# 2       56721  000000-3  0216537580            0    Friday  0.014499
# 3       35286  19440430  0132144161            0    Friday  0.014499
# 4       03173  19980315  6101082272            0    Friday  0.014499
# ...       ...       ...         ...          ...       ...       ...
# 999995  54890  19550418  8236558223            0  Saturday  0.014968
# 999996  74683  19150624  6790134432            0  Saturday  0.014968
# 999997  86805  19880628  3997657622            0  Saturday  0.014968
# 999998  49183  20120302  5935293731            0  Saturday  0.014968
# 999999  39491  19820826  5869926905            0  Saturday  0.014968
#
# [1000000 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   record       1000000 non-null  int64
#  1   date         1000000 non-null  datetime64[ns]
#  2   ssn          1000000 non-null  object
#  3   firstname    1000000 non-null  object
#  4   lastname     1000000 non-null  object
#  5   address      1000000 non-null  object
#  6   zip5         1000000 non-null  object
#  7   dob          1000000 non-null  object
#  8   homephone    1000000 non-null  object
#  9   fraud_label  1000000 non-null  int64
#  10  dow          1000000 non-null  object
#  11  dow_risk     1000000 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(8)
# memory usage: 91.6+ MB

# %% [markdown]
# # Make Some New Entities for Variables

# %%
data['name'] = data.firstname + data.lastname
data['fulladdress'] = data.address + data.zip5
data['name_dob'] = data.name + data.dob
data['name_fulladdress'] = data.name + data.fulladdress
data['name_homephone'] = data.name + data.homephone
data['fulladdress_dob'] = data.fulladdress + data.dob
data['fulladdress_homephone'] = data.fulladdress + data.homephone
data['dob_homephone'] = data.dob + data.homephone
data['homephone_name_dob'] = data.homephone + data.name_dob
data['fulladdress_name_dob'] = data.fulladdress + data.name_dob

# %%
data['name_zip5'] = data.name + data.zip5
data['name_address'] = data.name + data.address

data['firstname_dob'] = data.firstname + data.dob
data['firstname_address'] = data.firstname + data.address
data['firstname_zip5'] = data.firstname + data.zip5
data['firstname_homephone'] = data.firstname + data.homephone
data['firstname_fulladdress'] = data.firstname + data.fulladdress

data['lastname_dob'] = data.lastname + data.dob
data['lastname_address'] = data.lastname + data.address
data['lastname_zip5'] = data.lastname + data.zip5
data['lastname_homephone'] = data.lastname + data.homephone
data['lastname_fulladdress'] = data.lastname + data.fulladdress

# %%
for field in list(data.iloc[:,np.r_[3:9, 12:22]].columns):
    data['ssn_' + field] = data.ssn + data[field]

# %%
(data.columns)
# Out:
# Index(['record', 'date', 'ssn', 'firstname', 'lastname', 'address', 'zip5',
#        'dob', 'homephone', 'fraud_label', 'dow', 'dow_risk', 'name',
#        'fulladdress', 'name_dob', 'name_fulladdress', 'name_homephone',
#        'fulladdress_dob', 'fulladdress_homephone', 'dob_homephone',
#        'homephone_name_dob', 'fulladdress_name_dob', 'name_zip5',
#        'name_address', 'firstname_dob', 'firstname_address', 'firstname_zip5',
#        'firstname_homephone', 'firstname_fulladdress', 'lastname_dob',
#        'lastname_address', 'lastname_zip5', 'lastname_homephone',
#        'lastname_fulladdress', 'ssn_firstname', 'ssn_lastname', 'ssn_address',
#        'ssn_zip5', 'ssn_dob', 'ssn_homephone', 'ssn_name', 'ssn_fulladdress',
#        'ssn_name_dob', 'ssn_name_fulladdress', 'ssn_name_homephone',
#        'ssn_fulladdress_dob', 'ssn_fulladdress_homephone', 'ssn_dob_homephone',
#        'ssn_homephone_name_dob', 'ssn_fulladdress_name_dob'],
#       dtype='object')

# %%
attributes = list(data.iloc[:, np.r_[2, 5, 7, 8, 12:50]].columns)

# %%
len(attributes)
# Out:
# 42

# %%
data1 = data.copy()
vars = data.copy()
data1['check_date'] = data1.date
data1['check_record'] = data1.record
vars.shape
# Out:
# (1000000, 50)

# %% [markdown]
# # Velocity count and Days Since

# %%
import time
begin = time.time()
for entity in attributes:
    st = time.time()
    data_1 = data1[['record', 'date', entity]]
    data_r = data1[['check_record', 'check_date', entity]]
    temp = pd.merge(data_1, data_r, left_on = entity, right_on = entity)
    
    day_since_data = temp[temp.record > temp.check_record][['record', 'date', 'check_date']].groupby('record')[['date', 'check_date']].last()
    mapper = (day_since_data.date - day_since_data.check_date).dt.days
    vars[entity + '_day_since'] = vars.record.map(mapper)
    vars[entity + '_day_since'].fillna(365, inplace = True)
    print(f'\n{entity}_day_since ---> Done')
    
    for offset_t in [0, 1, 3, 7, 14, 30]:
        count_day_data = temp[(temp.check_date >= (temp.date - dt.timedelta(offset_t))) & (temp.record >= temp.check_record)]
        col_name = f'{entity}_count_{offset_t}'
        mapper2 = count_day_data.groupby('record')[entity].count()
        vars[col_name] = vars.record.map(mapper2)
        
        print(f'{entity}_count_{str(offset_t)} ---> Done')
    
    print(f'Run time for entity {entity} -------- {time.time()-st}s')
    
print(f'Total run time: {(time.time() - begin)/60}min')
# Out:
# ssn_day_since ---> Done
# ssn_count_0 ---> Done
# ssn_count_1 ---> Done
# ssn_count_3 ---> Done
# ssn_count_7 ---> Done
# ssn_count_14 ---> Done
# ssn_count_30 ---> Done
# Run time for entity ssn -------- 7.199325799942017s
#
# address_day_since ---> Done
# address_count_0 ---> Done
# address_count_1 ---> Done
# address_count_3 ---> Done
# address_count_7 ---> Done
# address_count_14 ---> Done
# address_count_30 ---> Done
# Run time for entity address -------- 7.7478954792022705s
#
# dob_day_since ---> Done
# dob_count_0 ---> Done
# dob_count_1 ---> Done
# dob_count_3 ---> Done
# dob_count_7 ---> Done
# dob_count_14 ---> Done
# dob_count_30 ---> Done
# Run time for entity dob -------- 41.6002721786499s
#
# homephone_day_since ---> Done
# homephone_count_0 ---> Done
# homephone_count_1 ---> Done
# homephone_count_3 ---> Done
# homephone_count_7 ---> Done
# homephone_count_14 ---> Done
# homephone_count_30 ---> Done
# Run time for entity homephone -------- 37.61509299278259s
#
# name_day_since ---> Done
# name_count_0 ---> Done
# name_count_1 ---> Done
# name_count_3 ---> Done
# name_count_7 ---> Done
# name_count_14 ---> Done
# name_count_30 ---> Done
# Run time for entity name -------- 10.11855435371399s
#
# fulladdress_day_since ---> Done
# fulladdress_count_0 ---> Done
# fulladdress_count_1 ---> Done
# fulladdress_count_3 ---> Done
# fulladdress_count_7 ---> Done
# fulladdress_count_14 ---> Done
# fulladdress_count_30 ---> Done
# Run time for entity fulladdress -------- 7.934748888015747s
#
# name_dob_day_since ---> Done
# name_dob_count_0 ---> Done
# name_dob_count_1 ---> Done
# name_dob_count_3 ---> Done
# name_dob_count_7 ---> Done
# name_dob_count_14 ---> Done
# name_dob_count_30 ---> Done
# Run time for entity name_dob -------- 6.9470624923706055s
#
# name_fulladdress_day_since ---> Done
# name_fulladdress_count_0 ---> Done
# name_fulladdress_count_1 ---> Done
# name_fulladdress_count_3 ---> Done
# name_fulladdress_count_7 ---> Done
# name_fulladdress_count_14 ---> Done
# name_fulladdress_count_30 ---> Done
# Run time for entity name_fulladdress -------- 7.495831489562988s
#
# name_homephone_day_since ---> Done
# name_homephone_count_0 ---> Done
# name_homephone_count_1 ---> Done
# name_homephone_count_3 ---> Done
# name_homephone_count_7 ---> Done
# name_homephone_count_14 ---> Done
# name_homephone_count_30 ---> Done
# Run time for entity name_homephone -------- 6.882075786590576s
#
# fulladdress_dob_day_since ---> Done
# fulladdress_dob_count_0 ---> Done
# fulladdress_dob_count_1 ---> Done
# fulladdress_dob_count_3 ---> Done
# fulladdress_dob_count_7 ---> Done
# fulladdress_dob_count_14 ---> Done
# fulladdress_dob_count_30 ---> Done
# Run time for entity fulladdress_dob -------- 6.90847110748291s
#
# fulladdress_homephone_day_since ---> Done
# fulladdress_homephone_count_0 ---> Done
# fulladdress_homephone_count_1 ---> Done
# fulladdress_homephone_count_3 ---> Done
# fulladdress_homephone_count_7 ---> Done
# fulladdress_homephone_count_14 ---> Done
# fulladdress_homephone_count_30 ---> Done
# Run time for entity fulladdress_homephone -------- 6.816596746444702s
#
# dob_homephone_day_since ---> Done
# dob_homephone_count_0 ---> Done
# dob_homephone_count_1 ---> Done
# dob_homephone_count_3 ---> Done
# dob_homephone_count_7 ---> Done
# dob_homephone_count_14 ---> Done
# dob_homephone_count_30 ---> Done
# Run time for entity dob_homephone -------- 6.934865474700928s
#
# homephone_name_dob_day_since ---> Done
# homephone_name_dob_count_0 ---> Done
# homephone_name_dob_count_1 ---> Done
# homephone_name_dob_count_3 ---> Done
# homephone_name_dob_count_7 ---> Done
# homephone_name_dob_count_14 ---> Done
# homephone_name_dob_count_30 ---> Done
# Run time for entity homephone_name_dob -------- 7.249903440475464s
#
# fulladdress_name_dob_day_since ---> Done
# fulladdress_name_dob_count_0 ---> Done
# fulladdress_name_dob_count_1 ---> Done
# fulladdress_name_dob_count_3 ---> Done
# fulladdress_name_dob_count_7 ---> Done
# C:\Users\Adreeta Guha\AppData\Local\Temp/ipykernel_15932/1878423025.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars[col_name] = vars.record.map(mapper2)
# fulladdress_name_dob_count_14 ---> Done
# fulladdress_name_dob_count_30 ---> Done
# Run time for entity fulladdress_name_dob -------- 7.131138324737549s
# C:\Users\Adreeta Guha\AppData\Local\Temp/ipykernel_15932/1878423025.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars[entity + '_day_since'] = vars.record.map(mapper)
# name_zip5_day_since ---> Done
# name_zip5_count_0 ---> Done
# name_zip5_count_1 ---> Done
# name_zip5_count_3 ---> Done
# name_zip5_count_7 ---> Done
# name_zip5_count_14 ---> Done
# name_zip5_count_30 ---> Done
# Run time for entity name_zip5 -------- 7.346109628677368s
#
# name_address_day_since ---> Done
# name_address_count_0 ---> Done
# name_address_count_1 ---> Done
# name_address_count_3 ---> Done
# name_address_count_7 ---> Done
# name_address_count_14 ---> Done
# name_address_count_30 ---> Done
# Run time for entity name_address -------- 7.117001295089722s
#
# firstname_dob_day_since ---> Done
# firstname_dob_count_0 ---> Done
# firstname_dob_count_1 ---> Done
# firstname_dob_count_3 ---> Done
# firstname_dob_count_7 ---> Done
# firstname_dob_count_14 ---> Done
# firstname_dob_count_30 ---> Done
# Run time for entity firstname_dob -------- 7.333938121795654s
#
# firstname_address_day_since ---> Done
# firstname_address_count_0 ---> Done
# firstname_address_count_1 ---> Done
# firstname_address_count_3 ---> Done
# firstname_address_count_7 ---> Done
# firstname_address_count_14 ---> Done
# firstname_address_count_30 ---> Done
# Run time for entity firstname_address -------- 7.134551286697388s
#
# firstname_zip5_day_since ---> Done
# firstname_zip5_count_0 ---> Done
# firstname_zip5_count_1 ---> Done
# firstname_zip5_count_3 ---> Done
# firstname_zip5_count_7 ---> Done
# firstname_zip5_count_14 ---> Done
# firstname_zip5_count_30 ---> Done
# Run time for entity firstname_zip5 -------- 8.00864577293396s
#
# firstname_homephone_day_since ---> Done
# firstname_homephone_count_0 ---> Done
# firstname_homephone_count_1 ---> Done
# firstname_homephone_count_3 ---> Done
# firstname_homephone_count_7 ---> Done
# firstname_homephone_count_14 ---> Done
# firstname_homephone_count_30 ---> Done
# Run time for entity firstname_homephone -------- 7.30754280090332s
#
# firstname_fulladdress_day_since ---> Done
# firstname_fulladdress_count_0 ---> Done
# firstname_fulladdress_count_1 ---> Done
# firstname_fulladdress_count_3 ---> Done
# firstname_fulladdress_count_7 ---> Done
# firstname_fulladdress_count_14 ---> Done
# firstname_fulladdress_count_30 ---> Done
# Run time for entity firstname_fulladdress -------- 7.307163238525391s
#
# lastname_dob_day_since ---> Done
# lastname_dob_count_0 ---> Done
# lastname_dob_count_1 ---> Done
# lastname_dob_count_3 ---> Done
# lastname_dob_count_7 ---> Done
# lastname_dob_count_14 ---> Done
# lastname_dob_count_30 ---> Done
# Run time for entity lastname_dob -------- 7.148303508758545s
#
# lastname_address_day_since ---> Done
# lastname_address_count_0 ---> Done
# lastname_address_count_1 ---> Done
# lastname_address_count_3 ---> Done
# lastname_address_count_7 ---> Done
# lastname_address_count_14 ---> Done
# lastname_address_count_30 ---> Done
# Run time for entity lastname_address -------- 7.122538089752197s
#
# lastname_zip5_day_since ---> Done
# lastname_zip5_count_0 ---> Done
# lastname_zip5_count_1 ---> Done
# lastname_zip5_count_3 ---> Done
# lastname_zip5_count_7 ---> Done
# lastname_zip5_count_14 ---> Done
# lastname_zip5_count_30 ---> Done
# Run time for entity lastname_zip5 -------- 7.6106836795806885s
#
# lastname_homephone_day_since ---> Done
# lastname_homephone_count_0 ---> Done
# lastname_homephone_count_1 ---> Done
# lastname_homephone_count_3 ---> Done
# lastname_homephone_count_7 ---> Done
# lastname_homephone_count_14 ---> Done
# lastname_homephone_count_30 ---> Done
# Run time for entity lastname_homephone -------- 6.941690921783447s
#
# lastname_fulladdress_day_since ---> Done
# lastname_fulladdress_count_0 ---> Done
# lastname_fulladdress_count_1 ---> Done
# lastname_fulladdress_count_3 ---> Done
# lastname_fulladdress_count_7 ---> Done
# lastname_fulladdress_count_14 ---> Done
# lastname_fulladdress_count_30 ---> Done
# Run time for entity lastname_fulladdress -------- 7.450562953948975s
#
# ssn_firstname_day_since ---> Done
# ssn_firstname_count_0 ---> Done
# ssn_firstname_count_1 ---> Done
# ssn_firstname_count_3 ---> Done
# ssn_firstname_count_7 ---> Done
# ssn_firstname_count_14 ---> Done
# ssn_firstname_count_30 ---> Done
# Run time for entity ssn_firstname -------- 7.4164886474609375s
#
# ssn_lastname_day_since ---> Done
# ssn_lastname_count_0 ---> Done
# ssn_lastname_count_1 ---> Done
# ssn_lastname_count_3 ---> Done
# ssn_lastname_count_7 ---> Done
# ssn_lastname_count_14 ---> Done
# ssn_lastname_count_30 ---> Done
# Run time for entity ssn_lastname -------- 7.251068115234375s
#
# ssn_address_day_since ---> Done
# ssn_address_count_0 ---> Done
# ssn_address_count_1 ---> Done
# ssn_address_count_3 ---> Done
# ssn_address_count_7 ---> Done
# ssn_address_count_14 ---> Done
# ssn_address_count_30 ---> Done
# Run time for entity ssn_address -------- 7.143723011016846s
#
# ssn_zip5_day_since ---> Done
# ssn_zip5_count_0 ---> Done
# ssn_zip5_count_1 ---> Done
# ssn_zip5_count_3 ---> Done
# ssn_zip5_count_7 ---> Done
# ssn_zip5_count_14 ---> Done
# ssn_zip5_count_30 ---> Done
# Run time for entity ssn_zip5 -------- 6.963750839233398s
#
# ssn_dob_day_since ---> Done
# ssn_dob_count_0 ---> Done
# ssn_dob_count_1 ---> Done
# ssn_dob_count_3 ---> Done
# ssn_dob_count_7 ---> Done
# ssn_dob_count_14 ---> Done
# ssn_dob_count_30 ---> Done
# Run time for entity ssn_dob -------- 7.161097288131714s
#
# ssn_homephone_day_since ---> Done
# ssn_homephone_count_0 ---> Done
# ssn_homephone_count_1 ---> Done
# ssn_homephone_count_3 ---> Done
# ssn_homephone_count_7 ---> Done
# ssn_homephone_count_14 ---> Done
# ssn_homephone_count_30 ---> Done
# Run time for entity ssn_homephone -------- 7.2488014698028564s
#
# ssn_name_day_since ---> Done
# ssn_name_count_0 ---> Done
# ssn_name_count_1 ---> Done
# ssn_name_count_3 ---> Done
# ssn_name_count_7 ---> Done
# ssn_name_count_14 ---> Done
# ssn_name_count_30 ---> Done
# Run time for entity ssn_name -------- 7.369974613189697s
#
# ssn_fulladdress_day_since ---> Done
# ssn_fulladdress_count_0 ---> Done
# ssn_fulladdress_count_1 ---> Done
# ssn_fulladdress_count_3 ---> Done
# ssn_fulladdress_count_7 ---> Done
# ssn_fulladdress_count_14 ---> Done
# ssn_fulladdress_count_30 ---> Done
# Run time for entity ssn_fulladdress -------- 6.938151121139526s
#
# ssn_name_dob_day_since ---> Done
# ssn_name_dob_count_0 ---> Done
# ssn_name_dob_count_1 ---> Done
# ssn_name_dob_count_3 ---> Done
# ssn_name_dob_count_7 ---> Done
# ssn_name_dob_count_14 ---> Done
# ssn_name_dob_count_30 ---> Done
# Run time for entity ssn_name_dob -------- 7.660428285598755s
#
# ssn_name_fulladdress_day_since ---> Done
# ssn_name_fulladdress_count_0 ---> Done
# ssn_name_fulladdress_count_1 ---> Done
# ssn_name_fulladdress_count_3 ---> Done
# ssn_name_fulladdress_count_7 ---> Done
# ssn_name_fulladdress_count_14 ---> Done
# ssn_name_fulladdress_count_30 ---> Done
# Run time for entity ssn_name_fulladdress -------- 7.451889991760254s
#
# ssn_name_homephone_day_since ---> Done
# ssn_name_homephone_count_0 ---> Done
# ssn_name_homephone_count_1 ---> Done
# ssn_name_homephone_count_3 ---> Done
# ssn_name_homephone_count_7 ---> Done
# ssn_name_homephone_count_14 ---> Done
# ssn_name_homephone_count_30 ---> Done
# Run time for entity ssn_name_homephone -------- 8.19515085220337s
#
# ssn_fulladdress_dob_day_since ---> Done
# ssn_fulladdress_dob_count_0 ---> Done
# ssn_fulladdress_dob_count_1 ---> Done
# ssn_fulladdress_dob_count_3 ---> Done
# ssn_fulladdress_dob_count_7 ---> Done
# ssn_fulladdress_dob_count_14 ---> Done
# ssn_fulladdress_dob_count_30 ---> Done
# Run time for entity ssn_fulladdress_dob -------- 7.48762583732605s
#
# ssn_fulladdress_homephone_day_since ---> Done
# ssn_fulladdress_homephone_count_0 ---> Done
# ssn_fulladdress_homephone_count_1 ---> Done
# ssn_fulladdress_homephone_count_3 ---> Done
# ssn_fulladdress_homephone_count_7 ---> Done
# ssn_fulladdress_homephone_count_14 ---> Done
# ssn_fulladdress_homephone_count_30 ---> Done
# Run time for entity ssn_fulladdress_homephone -------- 7.80673885345459s
#
# ssn_dob_homephone_day_since ---> Done
# ssn_dob_homephone_count_0 ---> Done
# ssn_dob_homephone_count_1 ---> Done
# ssn_dob_homephone_count_3 ---> Done
# ssn_dob_homephone_count_7 ---> Done
# ssn_dob_homephone_count_14 ---> Done
# ssn_dob_homephone_count_30 ---> Done
# Run time for entity ssn_dob_homephone -------- 7.219846248626709s
#
# ssn_homephone_name_dob_day_since ---> Done
# ssn_homephone_name_dob_count_0 ---> Done
# ssn_homephone_name_dob_count_1 ---> Done
# ssn_homephone_name_dob_count_3 ---> Done
# ssn_homephone_name_dob_count_7 ---> Done
# ssn_homephone_name_dob_count_14 ---> Done
# ssn_homephone_name_dob_count_30 ---> Done
# Run time for entity ssn_homephone_name_dob -------- 7.851980924606323s
# ssn_fulladdress_name_dob_day_since ---> Done
# ssn_fulladdress_name_dob_count_0 ---> Done
# ssn_fulladdress_name_dob_count_1 ---> Done
# ssn_fulladdress_name_dob_count_3 ---> Done
# ssn_fulladdress_name_dob_count_7 ---> Done
# ssn_fulladdress_name_dob_count_14 ---> Done
# ssn_fulladdress_name_dob_count_30 ---> Done
# Run time for entity ssn_fulladdress_name_dob -------- 7.554301977157593s
# Total run time: 6.252453311284383min

# %%
start = time.time()
for att in attributes:
    for d in ['0', '1']:
        for dd in ['3', '7', '14', '30']:
            vars[att + '_count_' + d + '_by_' + dd] = vars[att + '_count_' + d]/ (vars[att + '_count_' + dd]/ float(dd))

print(f'Total run time: {time.time() -start}s')
# Out:
# C:\Users\Adreeta Guha\AppData\Local\Temp/ipykernel_15932/4193723212.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars[att + '_count_' + d + '_by_' + dd] = vars[att + '_count_' + d]/ (vars[att + '_count_' + dd]/ float(dd))
# Total run time: 7.65793776512146s

# %%
vars
# Out:
#          record       date        ssn  firstname  lastname         address  \
# 0             1 2016-01-01  379070012   XRRAMMTR  SMJETJMJ   6861 EUTST PL
# 1             2 2016-01-01  387482503   MAMSTUJR  RTTEMRRR   7280 URASA PL
# 2             3 2016-01-01  200332444  SZMMUJEZS  EUSEZRAE   5581 RSREX LN
# 3             4 2016-01-01  747451317  SJJZSXRSZ  ETJXTXXS   1387 UJZXJ RD
# 4             5 2016-01-01  024065868  SSSXUEJMS  SSUUJXUZ    279 EAASA WY
# ...         ...        ...        ...        ...       ...             ...
# 999995   999996 2016-12-31  766104848  XUSAAURMZ  EJXXEXZX  8079 EJRUJ AVE
# 999996   999997 2016-12-31  445178058  SAAJJEMTX  UMAUETJX  4817 UMSXT AVE
# 999997   999998 2016-12-31  025283410  ESRXXRSUX  EUEJRJJE   7562 RJMAZ ST
# 999998   999999 2016-12-31  361232148  XXMZSRXMA  RSRSUJSS   3408 UZZAM WY
# 999999  1000000 2016-12-31  040027083  RXZXSMEZA  UTEAAZXU    112 UTTJT PL
#
#          zip5       dob   homephone  fraud_label  ...  \
# 0       02765  000000-1  1797504115            0  ...
# 1       57169  19340615  4164239415            1  ...
# 2       56721  000000-3  0216537580            0  ...
# 3       35286  19440430  0132144161            0  ...
# 4       03173  19980315  6101082272            0  ...
# ...       ...       ...         ...          ...  ...
# 999995  54890  19550418  8236558223            0  ...
# 999996  74683  19150624  6790134432            0  ...
# 999997  86805  19880628  3997657622            0  ...
# 999998  49183  20120302  5935293731            0  ...
# 999999  39491  19820826  5869926905            0  ...
#
#        ssn_homephone_name_dob_count_1_by_14  \
# 0                                      14.0
# 1                                      14.0
# 2                                      14.0
# 3                                      14.0
# 4                                      14.0
# ...                                     ...
# 999995                                 14.0
# 999996                                 14.0
# 999997                                 14.0
# 999998                                 14.0
# 999999                                 14.0
#
#         ssn_homephone_name_dob_count_1_by_30  \
# 0                                       30.0
# 1                                       30.0
# 2                                       30.0
# 3                                       30.0
# 4                                       30.0
# ...                                      ...
# 999995                                  30.0
# 999996                                  30.0
# 999997                                  30.0
# 999998                                  30.0
# 999999                                  30.0
#
#        ssn_fulladdress_name_dob_count_0_by_3  \
# 0                                        3.0
# 1                                        3.0
# 2                                        3.0
# 3                                        3.0
# 4                                        3.0
# ...                                      ...
# 999995                                   3.0
# 999996                                   3.0
# 999997                                   3.0
# 999998                                   3.0
# 999999                                   3.0
#
#        ssn_fulladdress_name_dob_count_0_by_7  \
# 0                                        7.0
# 1                                        7.0
# 2                                        7.0
# 3                                        7.0
# 4                                        7.0
# ...                                      ...
# 999995                                   7.0
# 999996                                   7.0
# 999997                                   7.0
# 999998                                   7.0
# 999999                                   7.0
#
#        ssn_fulladdress_name_dob_count_0_by_14  \
# 0                                        14.0
# 1                                        14.0
# 2                                        14.0
# 3                                        14.0
# 4                                        14.0
# ...                                       ...
# 999995                                   14.0
# 999996                                   14.0
# 999997                                   14.0
# 999998                                   14.0
# 999999                                   14.0
#
#        ssn_fulladdress_name_dob_count_0_by_30  \
# 0                                        30.0
# 1                                        30.0
# 2                                        30.0
# 3                                        30.0
# 4                                        30.0
# ...                                       ...
# 999995                                   30.0
# 999996                                   30.0
# 999997                                   30.0
# 999998                                   30.0
# 999999                                   30.0
#
#        ssn_fulladdress_name_dob_count_1_by_3  \
# 0                                        3.0
# 1                                        3.0
# 2                                        3.0
# 3                                        3.0
# 4                                        3.0
# ...                                      ...
# 999995                                   3.0
# 999996                                   3.0
# 999997                                   3.0
# 999998                                   3.0
# 999999                                   3.0
#
#        ssn_fulladdress_name_dob_count_1_by_7  \
# 0                                        7.0
# 1                                        7.0
# 2                                        7.0
# 3                                        7.0
# 4                                        7.0
# ...                                      ...
# 999995                                   7.0
# 999996                                   7.0
# 999997                                   7.0
# 999998                                   7.0
# 999999                                   7.0
#
#        ssn_fulladdress_name_dob_count_1_by_14  \
# 0                                        14.0
# 1                                        14.0
# 2                                        14.0
# 3                                        14.0
# 4                                        14.0
# ...                                       ...
# 999995                                   14.0
# 999996                                   14.0
# 999997                                   14.0
# 999998                                   14.0
# 999999                                   14.0
#
#        ssn_fulladdress_name_dob_count_1_by_30
# 0                                        30.0
# 1                                        30.0
# 2                                        30.0
# 3                                        30.0
# 4                                        30.0
# ...                                       ...
# 999995                                   30.0
# 999996                                   30.0
# 999997                                   30.0
# 999998                                   30.0
# 999999                                   30.0
#
# [1000000 rows x 680 columns]

# %%
att1 = ['ssn','fulladdress','name_dob','name_fulladdress','fulladdress_dob','dob_homephone',
        'ssn_lastname', 'ssn_zip5','ssn_name', 'ssn_fulladdress', 'ssn_name_dob','ssn_name_fulladdress']

# %%
begin = time.time()
for entity in att1:
    for field in att1:
        st = time.time()
        if field == entity:
            continue
        else:
            df_c = data1[[ 'record', 'date', entity]]
            df_d = data1[['check_record', 'check_date', entity, field]]
            temp = pd.merge(df_c, df_d, left_on=entity, right_on=entity)
            # number of unique for particular field
        for offset_t in [1, 3, 7, 14, 30, 60]:
            count_day_df = temp[(temp.check_date >= (temp.date - dt.timedelta (offset_t)))
                                & (temp.record >= temp.check_record)]
            col_name = f'{entity}unique_count_for{field}_{offset_t}'
            mapper = count_day_df.groupby(['record'])[field].nunique()
            vars[col_name] = vars.record.map (mapper)
                 
        print(f'Run time for entity {entity} in field {field}---{time.time() - st}s')
    print(f'Total run time: {(time.time() - begin) / 60}min')
# Out:
# C:\Users\Adreeta Guha\AppData\Local\Temp/ipykernel_15932/1547707734.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   vars[col_name] = vars.record.map (mapper)
# Run time for entity ssn in field fulladdress---10.994349956512451s
# Run time for entity ssn in field name_dob---11.051090240478516s
# Run time for entity ssn in field name_fulladdress---11.457787990570068s
# Run time for entity ssn in field fulladdress_dob---11.410568237304688s
# Run time for entity ssn in field dob_homephone---11.322988986968994s
# Run time for entity ssn in field ssn_lastname---10.638548374176025s
# Run time for entity ssn in field ssn_zip5---11.223715782165527s
# Run time for entity ssn in field ssn_name---11.127033710479736s
# Run time for entity ssn in field ssn_fulladdress---11.520916223526001s
# Run time for entity ssn in field ssn_name_dob---11.994221687316895s
# Run time for entity ssn in field ssn_name_fulladdress---11.823726415634155s
# Total run time: 2.076082460085551min
# Run time for entity fulladdress in field ssn---11.089638948440552s
# Run time for entity fulladdress in field name_dob---12.36081838607788s
# Run time for entity fulladdress in field name_fulladdress---12.427444696426392s
# Run time for entity fulladdress in field fulladdress_dob---10.938863277435303s
# Run time for entity fulladdress in field dob_homephone---9.406021118164062s
# Run time for entity fulladdress in field ssn_lastname---11.509414911270142s
# Run time for entity fulladdress in field ssn_zip5---11.293580055236816s
# Run time for entity fulladdress in field ssn_name---12.123807191848755s
# Run time for entity fulladdress in field ssn_fulladdress---11.625131845474243s
# Run time for entity fulladdress in field ssn_name_dob---12.550077676773071s
# Run time for entity fulladdress in field ssn_name_fulladdress---12.16217041015625s
# Total run time: 4.200865268707275min
# Run time for entity name_dob in field ssn---10.57087755203247s
# Run time for entity name_dob in field fulladdress---11.721771955490112s
# Run time for entity name_dob in field name_fulladdress---11.61067008972168s
# Run time for entity name_dob in field fulladdress_dob---10.951585292816162s
# Run time for entity name_dob in field dob_homephone---11.180596590042114s
# Run time for entity name_dob in field ssn_lastname---11.6122567653656s
# Run time for entity name_dob in field ssn_zip5---10.967561483383179s
# Run time for entity name_dob in field ssn_name---11.361790657043457s
# Run time for entity name_dob in field ssn_fulladdress---11.566327333450317s
# Run time for entity name_dob in field ssn_name_dob---10.88520884513855s
# Run time for entity name_dob in field ssn_name_fulladdress---11.8545982837677s
# Total run time: 6.272266352176667min
# Run time for entity name_fulladdress in field ssn---10.852873086929321s
# Run time for entity name_fulladdress in field fulladdress---11.026854038238525s
# Run time for entity name_fulladdress in field name_dob---11.244053363800049s
# Run time for entity name_fulladdress in field fulladdress_dob---11.226698160171509s
# Run time for entity name_fulladdress in field dob_homephone---11.257697105407715s
# Run time for entity name_fulladdress in field ssn_lastname---10.886818170547485s
# Run time for entity name_fulladdress in field ssn_zip5---10.6834077835083s
# Run time for entity name_fulladdress in field ssn_name---11.519394397735596s
# Run time for entity name_fulladdress in field ssn_fulladdress---11.240256071090698s
# Run time for entity name_fulladdress in field ssn_name_dob---11.619283199310303s
# Run time for entity name_fulladdress in field ssn_name_fulladdress---11.742300510406494s
# Total run time: 8.327393579483033min
# Run time for entity fulladdress_dob in field ssn---10.775988101959229s
# Run time for entity fulladdress_dob in field fulladdress---11.209766626358032s
# Run time for entity fulladdress_dob in field name_dob---10.873370885848999s
# Run time for entity fulladdress_dob in field name_fulladdress---11.79309868812561s
# Run time for entity fulladdress_dob in field dob_homephone---10.815939664840698s
# Run time for entity fulladdress_dob in field ssn_lastname---10.978386640548706s
# Run time for entity fulladdress_dob in field ssn_zip5---10.878820896148682s
# Run time for entity fulladdress_dob in field ssn_name---11.229464292526245s
# Run time for entity fulladdress_dob in field ssn_fulladdress---11.324851274490356s
# Run time for entity fulladdress_dob in field ssn_name_dob---11.396641731262207s
# Run time for entity fulladdress_dob in field ssn_name_fulladdress---12.053442001342773s
# Total run time: 10.383022940158844min
# Run time for entity dob_homephone in field ssn---10.551482677459717s
# Run time for entity dob_homephone in field fulladdress---11.157065391540527s
# Run time for entity dob_homephone in field name_dob---11.212690114974976s
# Run time for entity dob_homephone in field name_fulladdress---11.751651048660278s
# Run time for entity dob_homephone in field fulladdress_dob---11.811060905456543s
# Run time for entity dob_homephone in field ssn_lastname---11.134474754333496s
# Run time for entity dob_homephone in field ssn_zip5---10.582973003387451s
# Run time for entity dob_homephone in field ssn_name---11.21670389175415s
# Run time for entity dob_homephone in field ssn_fulladdress---11.322248220443726s
# Run time for entity dob_homephone in field ssn_name_dob---11.415507793426514s
# Run time for entity dob_homephone in field ssn_name_fulladdress---11.768737077713013s
# Total run time: 12.44851810534795min
# Run time for entity ssn_lastname in field ssn---10.534718036651611s
# Run time for entity ssn_lastname in field fulladdress---11.397277355194092s
# Run time for entity ssn_lastname in field name_dob---11.170798301696777s
# Run time for entity ssn_lastname in field name_fulladdress---11.79299545288086s
# Run time for entity ssn_lastname in field fulladdress_dob---11.475134372711182s
# Run time for entity ssn_lastname in field dob_homephone---11.036254405975342s
# Run time for entity ssn_lastname in field ssn_zip5---10.651586532592773s
# Run time for entity ssn_lastname in field ssn_name---10.858013391494751s
# Run time for entity ssn_lastname in field ssn_fulladdress---11.377042055130005s
# Run time for entity ssn_lastname in field ssn_name_dob---11.432164192199707s
# Run time for entity ssn_lastname in field ssn_name_fulladdress---11.666277885437012s
# Total run time: 14.505055805047354min
# Run time for entity ssn_zip5 in field ssn---10.765260219573975s
# Run time for entity ssn_zip5 in field fulladdress---11.009073734283447s
# Run time for entity ssn_zip5 in field name_dob---11.028391122817993s
# Run time for entity ssn_zip5 in field name_fulladdress---11.657177209854126s
# Run time for entity ssn_zip5 in field fulladdress_dob---11.042182922363281s
# Run time for entity ssn_zip5 in field dob_homephone---10.763432025909424s
# Run time for entity ssn_zip5 in field ssn_lastname---10.913402795791626s
# Run time for entity ssn_zip5 in field ssn_name---11.057717323303223s
# Run time for entity ssn_zip5 in field ssn_fulladdress---10.545677661895752s
# Run time for entity ssn_zip5 in field ssn_name_dob---11.341017246246338s
# Run time for entity ssn_zip5 in field ssn_name_fulladdress---11.594046831130981s
# Total run time: 16.53367878993352min
# Run time for entity ssn_name in field ssn---10.48332667350769s
# Run time for entity ssn_name in field fulladdress---11.113145112991333s
# Run time for entity ssn_name in field name_dob---11.404691219329834s
# Run time for entity ssn_name in field name_fulladdress---11.683318853378296s
# Run time for entity ssn_name in field fulladdress_dob---11.202826261520386s
# Run time for entity ssn_name in field dob_homephone---11.216191053390503s
# Run time for entity ssn_name in field ssn_lastname---10.794015645980835s
# Run time for entity ssn_name in field ssn_zip5---10.68498969078064s
# Run time for entity ssn_name in field ssn_fulladdress---11.31043028831482s
# Run time for entity ssn_name in field ssn_name_dob---11.442570209503174s
# Run time for entity ssn_name in field ssn_name_fulladdress---11.674855470657349s
# Total run time: 18.583851464589436min
# Run time for entity ssn_fulladdress in field ssn---10.50120496749878s
# Run time for entity ssn_fulladdress in field fulladdress---11.209740400314331s
# Run time for entity ssn_fulladdress in field name_dob---11.216332912445068s
# Run time for entity ssn_fulladdress in field name_fulladdress---11.546842813491821s
# Run time for entity ssn_fulladdress in field fulladdress_dob---11.371354341506958s
# Run time for entity ssn_fulladdress in field dob_homephone---10.830560684204102s
# Run time for entity ssn_fulladdress in field ssn_lastname---10.341638326644897s
# Run time for entity ssn_fulladdress in field ssn_zip5---10.57396674156189s
# Run time for entity ssn_fulladdress in field ssn_name---10.209332942962646s
# Run time for entity ssn_fulladdress in field ssn_name_dob---10.81854510307312s
# Run time for entity ssn_fulladdress in field ssn_name_fulladdress---11.290079832077026s
# Total run time: 20.582344782352447min
# Run time for entity ssn_name_dob in field ssn---10.74439024925232s
# Run time for entity ssn_name_dob in field fulladdress---11.005922555923462s
# Run time for entity ssn_name_dob in field name_dob---11.423345565795898s
# Run time for entity ssn_name_dob in field name_fulladdress---12.398865938186646s
# Run time for entity ssn_name_dob in field fulladdress_dob---11.43163251876831s
# Run time for entity ssn_name_dob in field dob_homephone---11.042142391204834s
# Run time for entity ssn_name_dob in field ssn_lastname---11.547970056533813s
# Run time for entity ssn_name_dob in field ssn_zip5---10.942262887954712s
# Run time for entity ssn_name_dob in field ssn_name---11.736201524734497s
# Run time for entity ssn_name_dob in field ssn_fulladdress---11.837607383728027s
# Run time for entity ssn_name_dob in field ssn_name_fulladdress---12.686304807662964s
# Total run time: 22.69562221368154min
# Run time for entity ssn_name_fulladdress in field ssn---10.964771270751953s
# Run time for entity ssn_name_fulladdress in field fulladdress---11.27850079536438s
# Run time for entity ssn_name_fulladdress in field name_dob---11.61188006401062s
# Run time for entity ssn_name_fulladdress in field name_fulladdress---11.869322776794434s
# Run time for entity ssn_name_fulladdress in field fulladdress_dob---11.591021299362183s
# Run time for entity ssn_name_fulladdress in field dob_homephone---11.208442449569702s
# Run time for entity ssn_name_fulladdress in field ssn_lastname---11.519654989242554s
# Run time for entity ssn_name_fulladdress in field ssn_zip5---10.767822265625s
# Run time for entity ssn_name_fulladdress in field ssn_name---11.477622270584106s
# Run time for entity ssn_name_fulladdress in field ssn_fulladdress---11.569708347320557s
# Run time for entity ssn_name_fulladdress in field ssn_name_dob---11.892096042633057s
# Total run time: 24.79146958986918min

# %%
vars
# Out:
#          record       date        ssn  firstname  lastname         address  \
# 0             1 2016-01-01  379070012   XRRAMMTR  SMJETJMJ   6861 EUTST PL
# 1             2 2016-01-01  387482503   MAMSTUJR  RTTEMRRR   7280 URASA PL
# 2             3 2016-01-01  200332444  SZMMUJEZS  EUSEZRAE   5581 RSREX LN
# 3             4 2016-01-01  747451317  SJJZSXRSZ  ETJXTXXS   1387 UJZXJ RD
# 4             5 2016-01-01  024065868  SSSXUEJMS  SSUUJXUZ    279 EAASA WY
# ...         ...        ...        ...        ...       ...             ...
# 999995   999996 2016-12-31  766104848  XUSAAURMZ  EJXXEXZX  8079 EJRUJ AVE
# 999996   999997 2016-12-31  445178058  SAAJJEMTX  UMAUETJX  4817 UMSXT AVE
# 999997   999998 2016-12-31  025283410  ESRXXRSUX  EUEJRJJE   7562 RJMAZ ST
# 999998   999999 2016-12-31  361232148  XXMZSRXMA  RSRSUJSS   3408 UZZAM WY
# 999999  1000000 2016-12-31  040027083  RXZXSMEZA  UTEAAZXU    112 UTTJT PL
#
#          zip5       dob   homephone  fraud_label  ...  \
# 0       02765  000000-1  1797504115            0  ...
# 1       57169  19340615  4164239415            1  ...
# 2       56721  000000-3  0216537580            0  ...
# 3       35286  19440430  0132144161            0  ...
# 4       03173  19980315  6101082272            0  ...
# ...       ...       ...         ...          ...  ...
# 999995  54890  19550418  8236558223            0  ...
# 999996  74683  19150624  6790134432            0  ...
# 999997  86805  19880628  3997657622            0  ...
# 999998  49183  20120302  5935293731            0  ...
# 999999  39491  19820826  5869926905            0  ...
#
#        ssn_name_fulladdressunique_count_forssn_fulladdress_7  \
# 0                                                       1
# 1                                                       1
# 2                                                       1
# 3                                                       1
# 4                                                       1
# ...                                                   ...
# 999995                                                  1
# 999996                                                  1
# 999997                                                  1
# 999998                                                  1
# 999999                                                  1
#
#         ssn_name_fulladdressunique_count_forssn_fulladdress_14  \
# 0                                                       1
# 1                                                       1
# 2                                                       1
# 3                                                       1
# 4                                                       1
# ...                                                   ...
# 999995                                                  1
# 999996                                                  1
# 999997                                                  1
# 999998                                                  1
# 999999                                                  1
#
#        ssn_name_fulladdressunique_count_forssn_fulladdress_30  \
# 0                                                       1
# 1                                                       1
# 2                                                       1
# 3                                                       1
# 4                                                       1
# ...                                                   ...
# 999995                                                  1
# 999996                                                  1
# 999997                                                  1
# 999998                                                  1
# 999999                                                  1
#
#        ssn_name_fulladdressunique_count_forssn_fulladdress_60  \
# 0                                                       1
# 1                                                       1
# 2                                                       1
# 3                                                       1
# 4                                                       1
# ...                                                   ...
# 999995                                                  1
# 999996                                                  1
# 999997                                                  1
# 999998                                                  1
# 999999                                                  1
#
#        ssn_name_fulladdressunique_count_forssn_name_dob_1  \
# 0                                                       1
# 1                                                       1
# 2                                                       1
# 3                                                       1
# 4                                                       1
# ...                                                   ...
# 999995                                                  1
# 999996                                                  1
# 999997                                                  1
# 999998                                                  1
# 999999                                                  1
#
#        ssn_name_fulladdressunique_count_forssn_name_dob_3  \
# 0                                                       1
# 1                                                       1
# 2                                                       1
# 3                                                       1
# 4                                                       1
# ...                                                   ...
# 999995                                                  1
# 999996                                                  1
# 999997                                                  1
# 999998                                                  1
# 999999                                                  1
#
#        ssn_name_fulladdressunique_count_forssn_name_dob_7  \
# 0                                                       1
# 1                                                       1
# 2                                                       1
# 3                                                       1
# 4                                                       1
# ...                                                   ...
# 999995                                                  1
# 999996                                                  1
# 999997                                                  1
# 999998                                                  1
# 999999                                                  1
#
#        ssn_name_fulladdressunique_count_forssn_name_dob_14  \
# 0                                                       1
# 1                                                       1
# 2                                                       1
# 3                                                       1
# 4                                                       1
# ...                                                   ...
# 999995                                                  1
# 999996                                                  1
# 999997                                                  1
# 999998                                                  1
# 999999                                                  1
#
#        ssn_name_fulladdressunique_count_forssn_name_dob_30  \
# 0                                                       1
# 1                                                       1
# 2                                                       1
# 3                                                       1
# 4                                                       1
# ...                                                   ...
# 999995                                                  1
# 999996                                                  1
# 999997                                                  1
# 999998                                                  1
# 999999                                                  1
#
#        ssn_name_fulladdressunique_count_forssn_name_dob_60
# 0                                                       1
# 1                                                       1
# 2                                                       1
# 3                                                       1
# 4                                                       1
# ...                                                   ...
# 999995                                                  1
# 999996                                                  1
# 999997                                                  1
# 999998                                                  1
# 999999                                                  1
#
# [1000000 rows x 1472 columns]

# %%
list(vars.columns)
# Out:
# ['record',
#  'date',
#  'ssn',
#  'firstname',
#  'lastname',
#  'address',
#  'zip5',
#  'dob',
#  'homephone',
#  'fraud_label',
#  'dow',
#  'dow_risk',
#  'name',
#  'fulladdress',
#  'name_dob',
#  'name_fulladdress',
#  'name_homephone',
#  'fulladdress_dob',
#  'fulladdress_homephone',
#  'dob_homephone',
#  'homephone_name_dob',
#  'fulladdress_name_dob',
#  'name_zip5',
#  'name_address',
#  'firstname_dob',
#  'firstname_address',
#  'firstname_zip5',
#  'firstname_homephone',
#  'firstname_fulladdress',
#  'lastname_dob',
#  'lastname_address',
#  'lastname_zip5',
#  'lastname_homephone',
#  'lastname_fulladdress',
#  'ssn_firstname',
#  'ssn_lastname',
#  'ssn_address',
#  'ssn_zip5',
#  'ssn_dob',
#  'ssn_homephone',
#  'ssn_name',
#  'ssn_fulladdress',
#  'ssn_name_dob',
#  'ssn_name_fulladdress',
#  'ssn_name_homephone',
#  'ssn_fulladdress_dob',
#  'ssn_fulladdress_homephone',
#  'ssn_dob_homephone',
#  'ssn_homephone_name_dob',
#  'ssn_fulladdress_name_dob',
#  'ssn_day_since',
#  'ssn_count_0',
#  'ssn_count_1',
#  'ssn_count_3',
#  'ssn_count_7',
#  'ssn_count_14',
#  'ssn_count_30',
#  'address_day_since',
#  'address_count_0',
#  'address_count_1',
#  'address_count_3',
#  'address_count_7',
#  'address_count_14',
#  'address_count_30',
#  'dob_day_since',
#  'dob_count_0',
#  'dob_count_1',
#  'dob_count_3',
#  'dob_count_7',
#  'dob_count_14',
#  'dob_count_30',
#  'homephone_day_since',
#  'homephone_count_0',
#  'homephone_count_1',
#  'homephone_count_3',
#  'homephone_count_7',
#  'homephone_count_14',
#  'homephone_count_30',
#  'name_day_since',
#  'name_count_0',
#  'name_count_1',
#  'name_count_3',
#  'name_count_7',
#  'name_count_14',
#  'name_count_30',
#  'fulladdress_day_since',
#  'fulladdress_count_0',
#  'fulladdress_count_1',
#  'fulladdress_count_3',
#  'fulladdress_count_7',
#  'fulladdress_count_14',
#  'fulladdress_count_30',
#  'name_dob_day_since',
#  'name_dob_count_0',
#  'name_dob_count_1',
#  'name_dob_count_3',
#  'name_dob_count_7',
#  'name_dob_count_14',
#  'name_dob_count_30',
#  'name_fulladdress_day_since',
#  'name_fulladdress_count_0',
#  'name_fulladdress_count_1',
#  'name_fulladdress_count_3',
#  'name_fulladdress_count_7',
#  'name_fulladdress_count_14',
#  'name_fulladdress_count_30',
#  'name_homephone_day_since',
#  'name_homephone_count_0',
#  'name_homephone_count_1',
#  'name_homephone_count_3',
#  'name_homephone_count_7',
#  'name_homephone_count_14',
#  'name_homephone_count_30',
#  'fulladdress_dob_day_since',
#  'fulladdress_dob_count_0',
#  'fulladdress_dob_count_1',
#  'fulladdress_dob_count_3',
#  'fulladdress_dob_count_7',
#  'fulladdress_dob_count_14',
#  'fulladdress_dob_count_30',
#  'fulladdress_homephone_day_since',
#  'fulladdress_homephone_count_0',
#  'fulladdress_homephone_count_1',
#  'fulladdress_homephone_count_3',
#  'fulladdress_homephone_count_7',
#  'fulladdress_homephone_count_14',
#  'fulladdress_homephone_count_30',
#  'dob_homephone_day_since',
#  'dob_homephone_count_0',
#  'dob_homephone_count_1',
#  'dob_homephone_count_3',
#  'dob_homephone_count_7',
#  'dob_homephone_count_14',
#  'dob_homephone_count_30',
#  'homephone_name_dob_day_since',
#  'homephone_name_dob_count_0',
#  'homephone_name_dob_count_1',
#  'homephone_name_dob_count_3',
#  'homephone_name_dob_count_7',
#  'homephone_name_dob_count_14',
#  'homephone_name_dob_count_30',
#  'fulladdress_name_dob_day_since',
#  'fulladdress_name_dob_count_0',
#  'fulladdress_name_dob_count_1',
#  'fulladdress_name_dob_count_3',
#  'fulladdress_name_dob_count_7',
#  'fulladdress_name_dob_count_14',
#  'fulladdress_name_dob_count_30',
#  'name_zip5_day_since',
#  'name_zip5_count_0',
#  'name_zip5_count_1',
#  'name_zip5_count_3',
#  'name_zip5_count_7',
#  'name_zip5_count_14',
#  'name_zip5_count_30',
#  'name_address_day_since',
#  'name_address_count_0',
#  'name_address_count_1',
#  'name_address_count_3',
#  'name_address_count_7',
#  'name_address_count_14',
#  'name_address_count_30',
#  'firstname_dob_day_since',
#  'firstname_dob_count_0',
#  'firstname_dob_count_1',
#  'firstname_dob_count_3',
#  'firstname_dob_count_7',
#  'firstname_dob_count_14',
#  'firstname_dob_count_30',
#  'firstname_address_day_since',
#  'firstname_address_count_0',
#  'firstname_address_count_1',
#  'firstname_address_count_3',
#  'firstname_address_count_7',
#  'firstname_address_count_14',
#  'firstname_address_count_30',
#  'firstname_zip5_day_since',
#  'firstname_zip5_count_0',
#  'firstname_zip5_count_1',
#  'firstname_zip5_count_3',
#  'firstname_zip5_count_7',
#  'firstname_zip5_count_14',
#  'firstname_zip5_count_30',
#  'firstname_homephone_day_since',
#  'firstname_homephone_count_0',
#  'firstname_homephone_count_1',
#  'firstname_homephone_count_3',
#  'firstname_homephone_count_7',
#  'firstname_homephone_count_14',
#  'firstname_homephone_count_30',
#  'firstname_fulladdress_day_since',
#  'firstname_fulladdress_count_0',
#  'firstname_fulladdress_count_1',
#  'firstname_fulladdress_count_3',
#  'firstname_fulladdress_count_7',
#  'firstname_fulladdress_count_14',
#  'firstname_fulladdress_count_30',
#  'lastname_dob_day_since',
#  'lastname_dob_count_0',
#  'lastname_dob_count_1',
#  'lastname_dob_count_3',
#  'lastname_dob_count_7',
#  'lastname_dob_count_14',
#  'lastname_dob_count_30',
#  'lastname_address_day_since',
#  'lastname_address_count_0',
#  'lastname_address_count_1',
#  'lastname_address_count_3',
#  'lastname_address_count_7',
#  'lastname_address_count_14',
#  'lastname_address_count_30',
#  'lastname_zip5_day_since',
#  'lastname_zip5_count_0',
#  'lastname_zip5_count_1',
#  'lastname_zip5_count_3',
#  'lastname_zip5_count_7',
#  'lastname_zip5_count_14',
#  'lastname_zip5_count_30',
#  'lastname_homephone_day_since',
#  'lastname_homephone_count_0',
#  'lastname_homephone_count_1',
#  'lastname_homephone_count_3',
#  'lastname_homephone_count_7',
#  'lastname_homephone_count_14',
#  'lastname_homephone_count_30',
#  'lastname_fulladdress_day_since',
#  'lastname_fulladdress_count_0',
#  'lastname_fulladdress_count_1',
#  'lastname_fulladdress_count_3',
#  'lastname_fulladdress_count_7',
#  'lastname_fulladdress_count_14',
#  'lastname_fulladdress_count_30',
#  'ssn_firstname_day_since',
#  'ssn_firstname_count_0',
#  'ssn_firstname_count_1',
#  'ssn_firstname_count_3',
#  'ssn_firstname_count_7',
#  'ssn_firstname_count_14',
#  'ssn_firstname_count_30',
#  'ssn_lastname_day_since',
#  'ssn_lastname_count_0',
#  'ssn_lastname_count_1',
#  'ssn_lastname_count_3',
#  'ssn_lastname_count_7',
#  'ssn_lastname_count_14',
#  'ssn_lastname_count_30',
#  'ssn_address_day_since',
#  'ssn_address_count_0',
#  'ssn_address_count_1',
#  'ssn_address_count_3',
#  'ssn_address_count_7',
#  'ssn_address_count_14',
#  'ssn_address_count_30',
#  'ssn_zip5_day_since',
#  'ssn_zip5_count_0',
#  'ssn_zip5_count_1',
#  'ssn_zip5_count_3',
#  'ssn_zip5_count_7',
#  'ssn_zip5_count_14',
#  'ssn_zip5_count_30',
#  'ssn_dob_day_since',
#  'ssn_dob_count_0',
#  'ssn_dob_count_1',
#  'ssn_dob_count_3',
#  'ssn_dob_count_7',
#  'ssn_dob_count_14',
#  'ssn_dob_count_30',
#  'ssn_homephone_day_since',
#  'ssn_homephone_count_0',
#  'ssn_homephone_count_1',
#  'ssn_homephone_count_3',
#  'ssn_homephone_count_7',
#  'ssn_homephone_count_14',
#  'ssn_homephone_count_30',
#  'ssn_name_day_since',
#  'ssn_name_count_0',
#  'ssn_name_count_1',
#  'ssn_name_count_3',
#  'ssn_name_count_7',
#  'ssn_name_count_14',
#  'ssn_name_count_30',
#  'ssn_fulladdress_day_since',
#  'ssn_fulladdress_count_0',
#  'ssn_fulladdress_count_1',
#  'ssn_fulladdress_count_3',
#  'ssn_fulladdress_count_7',
#  'ssn_fulladdress_count_14',
#  'ssn_fulladdress_count_30',
#  'ssn_name_dob_day_since',
#  'ssn_name_dob_count_0',
#  'ssn_name_dob_count_1',
#  'ssn_name_dob_count_3',
#  'ssn_name_dob_count_7',
#  'ssn_name_dob_count_14',
#  'ssn_name_dob_count_30',
#  'ssn_name_fulladdress_day_since',
#  'ssn_name_fulladdress_count_0',
#  'ssn_name_fulladdress_count_1',
#  'ssn_name_fulladdress_count_3',
#  'ssn_name_fulladdress_count_7',
#  'ssn_name_fulladdress_count_14',
#  'ssn_name_fulladdress_count_30',
#  'ssn_name_homephone_day_since',
#  'ssn_name_homephone_count_0',
#  'ssn_name_homephone_count_1',
#  'ssn_name_homephone_count_3',
#  'ssn_name_homephone_count_7',
#  'ssn_name_homephone_count_14',
#  'ssn_name_homephone_count_30',
#  'ssn_fulladdress_dob_day_since',
#  'ssn_fulladdress_dob_count_0',
#  'ssn_fulladdress_dob_count_1',
#  'ssn_fulladdress_dob_count_3',
#  'ssn_fulladdress_dob_count_7',
#  'ssn_fulladdress_dob_count_14',
#  'ssn_fulladdress_dob_count_30',
#  'ssn_fulladdress_homephone_day_since',
#  'ssn_fulladdress_homephone_count_0',
#  'ssn_fulladdress_homephone_count_1',
#  'ssn_fulladdress_homephone_count_3',
#  'ssn_fulladdress_homephone_count_7',
#  'ssn_fulladdress_homephone_count_14',
#  'ssn_fulladdress_homephone_count_30',
#  'ssn_dob_homephone_day_since',
#  'ssn_dob_homephone_count_0',
#  'ssn_dob_homephone_count_1',
#  'ssn_dob_homephone_count_3',
#  'ssn_dob_homephone_count_7',
#  'ssn_dob_homephone_count_14',
#  'ssn_dob_homephone_count_30',
#  'ssn_homephone_name_dob_day_since',
#  'ssn_homephone_name_dob_count_0',
#  'ssn_homephone_name_dob_count_1',
#  'ssn_homephone_name_dob_count_3',
#  'ssn_homephone_name_dob_count_7',
#  'ssn_homephone_name_dob_count_14',
#  'ssn_homephone_name_dob_count_30',
#  'ssn_fulladdress_name_dob_day_since',
#  'ssn_fulladdress_name_dob_count_0',
#  'ssn_fulladdress_name_dob_count_1',
#  'ssn_fulladdress_name_dob_count_3',
#  'ssn_fulladdress_name_dob_count_7',
#  'ssn_fulladdress_name_dob_count_14',
#  'ssn_fulladdress_name_dob_count_30',
#  'ssn_count_0_by_3',
#  'ssn_count_0_by_7',
#  'ssn_count_0_by_14',
#  'ssn_count_0_by_30',
#  'ssn_count_1_by_3',
#  'ssn_count_1_by_7',
#  'ssn_count_1_by_14',
#  'ssn_count_1_by_30',
#  'address_count_0_by_3',
#  'address_count_0_by_7',
#  'address_count_0_by_14',
#  'address_count_0_by_30',
#  'address_count_1_by_3',
#  'address_count_1_by_7',
#  'address_count_1_by_14',
#  'address_count_1_by_30',
#  'dob_count_0_by_3',
#  'dob_count_0_by_7',
#  'dob_count_0_by_14',
#  'dob_count_0_by_30',
#  'dob_count_1_by_3',
#  'dob_count_1_by_7',
#  'dob_count_1_by_14',
#  'dob_count_1_by_30',
#  'homephone_count_0_by_3',
#  'homephone_count_0_by_7',
#  'homephone_count_0_by_14',
#  'homephone_count_0_by_30',
#  'homephone_count_1_by_3',
#  'homephone_count_1_by_7',
#  'homephone_count_1_by_14',
#  'homephone_count_1_by_30',
#  'name_count_0_by_3',
#  'name_count_0_by_7',
#  'name_count_0_by_14',
#  'name_count_0_by_30',
#  'name_count_1_by_3',
#  'name_count_1_by_7',
#  'name_count_1_by_14',
#  'name_count_1_by_30',
#  'fulladdress_count_0_by_3',
#  'fulladdress_count_0_by_7',
#  'fulladdress_count_0_by_14',
#  'fulladdress_count_0_by_30',
#  'fulladdress_count_1_by_3',
#  'fulladdress_count_1_by_7',
#  'fulladdress_count_1_by_14',
#  'fulladdress_count_1_by_30',
#  'name_dob_count_0_by_3',
#  'name_dob_count_0_by_7',
#  'name_dob_count_0_by_14',
#  'name_dob_count_0_by_30',
#  'name_dob_count_1_by_3',
#  'name_dob_count_1_by_7',
#  'name_dob_count_1_by_14',
#  'name_dob_count_1_by_30',
#  'name_fulladdress_count_0_by_3',
#  'name_fulladdress_count_0_by_7',
#  'name_fulladdress_count_0_by_14',
#  'name_fulladdress_count_0_by_30',
#  'name_fulladdress_count_1_by_3',
#  'name_fulladdress_count_1_by_7',
#  'name_fulladdress_count_1_by_14',
#  'name_fulladdress_count_1_by_30',
#  'name_homephone_count_0_by_3',
#  'name_homephone_count_0_by_7',
#  'name_homephone_count_0_by_14',
#  'name_homephone_count_0_by_30',
#  'name_homephone_count_1_by_3',
#  'name_homephone_count_1_by_7',
#  'name_homephone_count_1_by_14',
#  'name_homephone_count_1_by_30',
#  'fulladdress_dob_count_0_by_3',
#  'fulladdress_dob_count_0_by_7',
#  'fulladdress_dob_count_0_by_14',
#  'fulladdress_dob_count_0_by_30',
#  'fulladdress_dob_count_1_by_3',
#  'fulladdress_dob_count_1_by_7',
#  'fulladdress_dob_count_1_by_14',
#  'fulladdress_dob_count_1_by_30',
#  'fulladdress_homephone_count_0_by_3',
#  'fulladdress_homephone_count_0_by_7',
#  'fulladdress_homephone_count_0_by_14',
#  'fulladdress_homephone_count_0_by_30',
#  'fulladdress_homephone_count_1_by_3',
#  'fulladdress_homephone_count_1_by_7',
#  'fulladdress_homephone_count_1_by_14',
#  'fulladdress_homephone_count_1_by_30',
#  'dob_homephone_count_0_by_3',
#  'dob_homephone_count_0_by_7',
#  'dob_homephone_count_0_by_14',
#  'dob_homephone_count_0_by_30',
#  'dob_homephone_count_1_by_3',
#  'dob_homephone_count_1_by_7',
#  'dob_homephone_count_1_by_14',
#  'dob_homephone_count_1_by_30',
#  'homephone_name_dob_count_0_by_3',
#  'homephone_name_dob_count_0_by_7',
#  'homephone_name_dob_count_0_by_14',
#  'homephone_name_dob_count_0_by_30',
#  'homephone_name_dob_count_1_by_3',
#  'homephone_name_dob_count_1_by_7',
#  'homephone_name_dob_count_1_by_14',
#  'homephone_name_dob_count_1_by_30',
#  'fulladdress_name_dob_count_0_by_3',
#  'fulladdress_name_dob_count_0_by_7',
#  'fulladdress_name_dob_count_0_by_14',
#  'fulladdress_name_dob_count_0_by_30',
#  'fulladdress_name_dob_count_1_by_3',
#  'fulladdress_name_dob_count_1_by_7',
#  'fulladdress_name_dob_count_1_by_14',
#  'fulladdress_name_dob_count_1_by_30',
#  'name_zip5_count_0_by_3',
#  'name_zip5_count_0_by_7',
#  'name_zip5_count_0_by_14',
#  'name_zip5_count_0_by_30',
#  'name_zip5_count_1_by_3',
#  'name_zip5_count_1_by_7',
#  'name_zip5_count_1_by_14',
#  'name_zip5_count_1_by_30',
#  'name_address_count_0_by_3',
#  'name_address_count_0_by_7',
#  'name_address_count_0_by_14',
#  'name_address_count_0_by_30',
#  'name_address_count_1_by_3',
#  'name_address_count_1_by_7',
#  'name_address_count_1_by_14',
#  'name_address_count_1_by_30',
#  'firstname_dob_count_0_by_3',
#  'firstname_dob_count_0_by_7',
#  'firstname_dob_count_0_by_14',
#  'firstname_dob_count_0_by_30',
#  'firstname_dob_count_1_by_3',
#  'firstname_dob_count_1_by_7',
#  'firstname_dob_count_1_by_14',
#  'firstname_dob_count_1_by_30',
#  'firstname_address_count_0_by_3',
#  'firstname_address_count_0_by_7',
#  'firstname_address_count_0_by_14',
#  'firstname_address_count_0_by_30',
#  'firstname_address_count_1_by_3',
#  'firstname_address_count_1_by_7',
#  'firstname_address_count_1_by_14',
#  'firstname_address_count_1_by_30',
#  'firstname_zip5_count_0_by_3',
#  'firstname_zip5_count_0_by_7',
#  'firstname_zip5_count_0_by_14',
#  'firstname_zip5_count_0_by_30',
#  'firstname_zip5_count_1_by_3',
#  'firstname_zip5_count_1_by_7',
#  'firstname_zip5_count_1_by_14',
#  'firstname_zip5_count_1_by_30',
#  'firstname_homephone_count_0_by_3',
#  'firstname_homephone_count_0_by_7',
#  'firstname_homephone_count_0_by_14',
#  'firstname_homephone_count_0_by_30',
#  'firstname_homephone_count_1_by_3',
#  'firstname_homephone_count_1_by_7',
#  'firstname_homephone_count_1_by_14',
#  'firstname_homephone_count_1_by_30',
#  'firstname_fulladdress_count_0_by_3',
#  'firstname_fulladdress_count_0_by_7',
#  'firstname_fulladdress_count_0_by_14',
#  'firstname_fulladdress_count_0_by_30',
#  'firstname_fulladdress_count_1_by_3',
#  'firstname_fulladdress_count_1_by_7',
#  'firstname_fulladdress_count_1_by_14',
#  'firstname_fulladdress_count_1_by_30',
#  'lastname_dob_count_0_by_3',
#  'lastname_dob_count_0_by_7',
#  'lastname_dob_count_0_by_14',
#  'lastname_dob_count_0_by_30',
#  'lastname_dob_count_1_by_3',
#  'lastname_dob_count_1_by_7',
#  'lastname_dob_count_1_by_14',
#  'lastname_dob_count_1_by_30',
#  'lastname_address_count_0_by_3',
#  'lastname_address_count_0_by_7',
#  'lastname_address_count_0_by_14',
#  'lastname_address_count_0_by_30',
#  'lastname_address_count_1_by_3',
#  'lastname_address_count_1_by_7',
#  'lastname_address_count_1_by_14',
#  'lastname_address_count_1_by_30',
#  'lastname_zip5_count_0_by_3',
#  'lastname_zip5_count_0_by_7',
#  'lastname_zip5_count_0_by_14',
#  'lastname_zip5_count_0_by_30',
#  'lastname_zip5_count_1_by_3',
#  'lastname_zip5_count_1_by_7',
#  'lastname_zip5_count_1_by_14',
#  'lastname_zip5_count_1_by_30',
#  'lastname_homephone_count_0_by_3',
#  'lastname_homephone_count_0_by_7',
#  'lastname_homephone_count_0_by_14',
#  'lastname_homephone_count_0_by_30',
#  'lastname_homephone_count_1_by_3',
#  'lastname_homephone_count_1_by_7',
#  'lastname_homephone_count_1_by_14',
#  'lastname_homephone_count_1_by_30',
#  'lastname_fulladdress_count_0_by_3',
#  'lastname_fulladdress_count_0_by_7',
#  'lastname_fulladdress_count_0_by_14',
#  'lastname_fulladdress_count_0_by_30',
#  'lastname_fulladdress_count_1_by_3',
#  'lastname_fulladdress_count_1_by_7',
#  'lastname_fulladdress_count_1_by_14',
#  'lastname_fulladdress_count_1_by_30',
#  'ssn_firstname_count_0_by_3',
#  'ssn_firstname_count_0_by_7',
#  'ssn_firstname_count_0_by_14',
#  'ssn_firstname_count_0_by_30',
#  'ssn_firstname_count_1_by_3',
#  'ssn_firstname_count_1_by_7',
#  'ssn_firstname_count_1_by_14',
#  'ssn_firstname_count_1_by_30',
#  'ssn_lastname_count_0_by_3',
#  'ssn_lastname_count_0_by_7',
#  'ssn_lastname_count_0_by_14',
#  'ssn_lastname_count_0_by_30',
#  'ssn_lastname_count_1_by_3',
#  'ssn_lastname_count_1_by_7',
#  'ssn_lastname_count_1_by_14',
#  'ssn_lastname_count_1_by_30',
#  'ssn_address_count_0_by_3',
#  'ssn_address_count_0_by_7',
#  'ssn_address_count_0_by_14',
#  'ssn_address_count_0_by_30',
#  'ssn_address_count_1_by_3',
#  'ssn_address_count_1_by_7',
#  'ssn_address_count_1_by_14',
#  'ssn_address_count_1_by_30',
#  'ssn_zip5_count_0_by_3',
#  'ssn_zip5_count_0_by_7',
#  'ssn_zip5_count_0_by_14',
#  'ssn_zip5_count_0_by_30',
#  'ssn_zip5_count_1_by_3',
#  'ssn_zip5_count_1_by_7',
#  'ssn_zip5_count_1_by_14',
#  'ssn_zip5_count_1_by_30',
#  'ssn_dob_count_0_by_3',
#  'ssn_dob_count_0_by_7',
#  'ssn_dob_count_0_by_14',
#  'ssn_dob_count_0_by_30',
#  'ssn_dob_count_1_by_3',
#  'ssn_dob_count_1_by_7',
#  'ssn_dob_count_1_by_14',
#  'ssn_dob_count_1_by_30',
#  'ssn_homephone_count_0_by_3',
#  'ssn_homephone_count_0_by_7',
#  'ssn_homephone_count_0_by_14',
#  'ssn_homephone_count_0_by_30',
#  'ssn_homephone_count_1_by_3',
#  'ssn_homephone_count_1_by_7',
#  'ssn_homephone_count_1_by_14',
#  'ssn_homephone_count_1_by_30',
#  'ssn_name_count_0_by_3',
#  'ssn_name_count_0_by_7',
#  'ssn_name_count_0_by_14',
#  'ssn_name_count_0_by_30',
#  'ssn_name_count_1_by_3',
#  'ssn_name_count_1_by_7',
#  'ssn_name_count_1_by_14',
#  'ssn_name_count_1_by_30',
#  'ssn_fulladdress_count_0_by_3',
#  'ssn_fulladdress_count_0_by_7',
#  'ssn_fulladdress_count_0_by_14',
#  'ssn_fulladdress_count_0_by_30',
#  'ssn_fulladdress_count_1_by_3',
#  'ssn_fulladdress_count_1_by_7',
#  'ssn_fulladdress_count_1_by_14',
#  'ssn_fulladdress_count_1_by_30',
#  'ssn_name_dob_count_0_by_3',
#  'ssn_name_dob_count_0_by_7',
#  'ssn_name_dob_count_0_by_14',
#  'ssn_name_dob_count_0_by_30',
#  'ssn_name_dob_count_1_by_3',
#  'ssn_name_dob_count_1_by_7',
#  'ssn_name_dob_count_1_by_14',
#  'ssn_name_dob_count_1_by_30',
#  'ssn_name_fulladdress_count_0_by_3',
#  'ssn_name_fulladdress_count_0_by_7',
#  'ssn_name_fulladdress_count_0_by_14',
#  'ssn_name_fulladdress_count_0_by_30',
#  'ssn_name_fulladdress_count_1_by_3',
#  'ssn_name_fulladdress_count_1_by_7',
#  'ssn_name_fulladdress_count_1_by_14',
#  'ssn_name_fulladdress_count_1_by_30',
#  'ssn_name_homephone_count_0_by_3',
#  'ssn_name_homephone_count_0_by_7',
#  'ssn_name_homephone_count_0_by_14',
#  'ssn_name_homephone_count_0_by_30',
#  'ssn_name_homephone_count_1_by_3',
#  'ssn_name_homephone_count_1_by_7',
#  'ssn_name_homephone_count_1_by_14',
#  'ssn_name_homephone_count_1_by_30',
#  'ssn_fulladdress_dob_count_0_by_3',
#  'ssn_fulladdress_dob_count_0_by_7',
#  'ssn_fulladdress_dob_count_0_by_14',
#  'ssn_fulladdress_dob_count_0_by_30',
#  'ssn_fulladdress_dob_count_1_by_3',
#  'ssn_fulladdress_dob_count_1_by_7',
#  'ssn_fulladdress_dob_count_1_by_14',
#  'ssn_fulladdress_dob_count_1_by_30',
#  'ssn_fulladdress_homephone_count_0_by_3',
#  'ssn_fulladdress_homephone_count_0_by_7',
#  'ssn_fulladdress_homephone_count_0_by_14',
#  'ssn_fulladdress_homephone_count_0_by_30',
#  'ssn_fulladdress_homephone_count_1_by_3',
#  'ssn_fulladdress_homephone_count_1_by_7',
#  'ssn_fulladdress_homephone_count_1_by_14',
#  'ssn_fulladdress_homephone_count_1_by_30',
#  'ssn_dob_homephone_count_0_by_3',
#  'ssn_dob_homephone_count_0_by_7',
#  'ssn_dob_homephone_count_0_by_14',
#  'ssn_dob_homephone_count_0_by_30',
#  'ssn_dob_homephone_count_1_by_3',
#  'ssn_dob_homephone_count_1_by_7',
#  'ssn_dob_homephone_count_1_by_14',
#  'ssn_dob_homephone_count_1_by_30',
#  'ssn_homephone_name_dob_count_0_by_3',
#  'ssn_homephone_name_dob_count_0_by_7',
#  'ssn_homephone_name_dob_count_0_by_14',
#  'ssn_homephone_name_dob_count_0_by_30',
#  'ssn_homephone_name_dob_count_1_by_3',
#  'ssn_homephone_name_dob_count_1_by_7',
#  'ssn_homephone_name_dob_count_1_by_14',
#  'ssn_homephone_name_dob_count_1_by_30',
#  'ssn_fulladdress_name_dob_count_0_by_3',
#  'ssn_fulladdress_name_dob_count_0_by_7',
#  'ssn_fulladdress_name_dob_count_0_by_14',
#  'ssn_fulladdress_name_dob_count_0_by_30',
#  'ssn_fulladdress_name_dob_count_1_by_3',
#  'ssn_fulladdress_name_dob_count_1_by_7',
#  'ssn_fulladdress_name_dob_count_1_by_14',
#  'ssn_fulladdress_name_dob_count_1_by_30',
#  'ssnunique_count_forfulladdress_1',
#  'ssnunique_count_forfulladdress_3',
#  'ssnunique_count_forfulladdress_7',
#  'ssnunique_count_forfulladdress_14',
#  'ssnunique_count_forfulladdress_30',
#  'ssnunique_count_forfulladdress_60',
#  'ssnunique_count_forname_dob_1',
#  'ssnunique_count_forname_dob_3',
#  'ssnunique_count_forname_dob_7',
#  'ssnunique_count_forname_dob_14',
#  'ssnunique_count_forname_dob_30',
#  'ssnunique_count_forname_dob_60',
#  'ssnunique_count_forname_fulladdress_1',
#  'ssnunique_count_forname_fulladdress_3',
#  'ssnunique_count_forname_fulladdress_7',
#  'ssnunique_count_forname_fulladdress_14',
#  'ssnunique_count_forname_fulladdress_30',
#  'ssnunique_count_forname_fulladdress_60',
#  'ssnunique_count_forfulladdress_dob_1',
#  'ssnunique_count_forfulladdress_dob_3',
#  'ssnunique_count_forfulladdress_dob_7',
#  'ssnunique_count_forfulladdress_dob_14',
#  'ssnunique_count_forfulladdress_dob_30',
#  'ssnunique_count_forfulladdress_dob_60',
#  'ssnunique_count_fordob_homephone_1',
#  'ssnunique_count_fordob_homephone_3',
#  'ssnunique_count_fordob_homephone_7',
#  'ssnunique_count_fordob_homephone_14',
#  'ssnunique_count_fordob_homephone_30',
#  'ssnunique_count_fordob_homephone_60',
#  'ssnunique_count_forssn_lastname_1',
#  'ssnunique_count_forssn_lastname_3',
#  'ssnunique_count_forssn_lastname_7',
#  'ssnunique_count_forssn_lastname_14',
#  'ssnunique_count_forssn_lastname_30',
#  'ssnunique_count_forssn_lastname_60',
#  'ssnunique_count_forssn_zip5_1',
#  'ssnunique_count_forssn_zip5_3',
#  'ssnunique_count_forssn_zip5_7',
#  'ssnunique_count_forssn_zip5_14',
#  'ssnunique_count_forssn_zip5_30',
#  'ssnunique_count_forssn_zip5_60',
#  'ssnunique_count_forssn_name_1',
#  'ssnunique_count_forssn_name_3',
#  'ssnunique_count_forssn_name_7',
#  'ssnunique_count_forssn_name_14',
#  'ssnunique_count_forssn_name_30',
#  'ssnunique_count_forssn_name_60',
#  'ssnunique_count_forssn_fulladdress_1',
#  'ssnunique_count_forssn_fulladdress_3',
#  'ssnunique_count_forssn_fulladdress_7',
#  'ssnunique_count_forssn_fulladdress_14',
#  'ssnunique_count_forssn_fulladdress_30',
#  'ssnunique_count_forssn_fulladdress_60',
#  'ssnunique_count_forssn_name_dob_1',
#  'ssnunique_count_forssn_name_dob_3',
#  'ssnunique_count_forssn_name_dob_7',
#  'ssnunique_count_forssn_name_dob_14',
#  'ssnunique_count_forssn_name_dob_30',
#  'ssnunique_count_forssn_name_dob_60',
#  'ssnunique_count_forssn_name_fulladdress_1',
#  'ssnunique_count_forssn_name_fulladdress_3',
#  'ssnunique_count_forssn_name_fulladdress_7',
#  'ssnunique_count_forssn_name_fulladdress_14',
#  'ssnunique_count_forssn_name_fulladdress_30',
#  'ssnunique_count_forssn_name_fulladdress_60',
#  'fulladdressunique_count_forssn_1',
#  'fulladdressunique_count_forssn_3',
#  'fulladdressunique_count_forssn_7',
#  'fulladdressunique_count_forssn_14',
#  'fulladdressunique_count_forssn_30',
#  'fulladdressunique_count_forssn_60',
#  'fulladdressunique_count_forname_dob_1',
#  'fulladdressunique_count_forname_dob_3',
#  'fulladdressunique_count_forname_dob_7',
#  'fulladdressunique_count_forname_dob_14',
#  'fulladdressunique_count_forname_dob_30',
#  'fulladdressunique_count_forname_dob_60',
#  'fulladdressunique_count_forname_fulladdress_1',
#  'fulladdressunique_count_forname_fulladdress_3',
#  'fulladdressunique_count_forname_fulladdress_7',
#  'fulladdressunique_count_forname_fulladdress_14',
#  'fulladdressunique_count_forname_fulladdress_30',
#  'fulladdressunique_count_forname_fulladdress_60',
#  'fulladdressunique_count_forfulladdress_dob_1',
#  'fulladdressunique_count_forfulladdress_dob_3',
#  'fulladdressunique_count_forfulladdress_dob_7',
#  'fulladdressunique_count_forfulladdress_dob_14',
#  'fulladdressunique_count_forfulladdress_dob_30',
#  'fulladdressunique_count_forfulladdress_dob_60',
#  'fulladdressunique_count_fordob_homephone_1',
#  'fulladdressunique_count_fordob_homephone_3',
#  'fulladdressunique_count_fordob_homephone_7',
#  'fulladdressunique_count_fordob_homephone_14',
#  'fulladdressunique_count_fordob_homephone_30',
#  'fulladdressunique_count_fordob_homephone_60',
#  'fulladdressunique_count_forssn_lastname_1',
#  'fulladdressunique_count_forssn_lastname_3',
#  'fulladdressunique_count_forssn_lastname_7',
#  'fulladdressunique_count_forssn_lastname_14',
#  'fulladdressunique_count_forssn_lastname_30',
#  'fulladdressunique_count_forssn_lastname_60',
#  'fulladdressunique_count_forssn_zip5_1',
#  'fulladdressunique_count_forssn_zip5_3',
#  'fulladdressunique_count_forssn_zip5_7',
#  'fulladdressunique_count_forssn_zip5_14',
#  'fulladdressunique_count_forssn_zip5_30',
#  'fulladdressunique_count_forssn_zip5_60',
#  'fulladdressunique_count_forssn_name_1',
#  'fulladdressunique_count_forssn_name_3',
#  'fulladdressunique_count_forssn_name_7',
#  'fulladdressunique_count_forssn_name_14',
#  'fulladdressunique_count_forssn_name_30',
#  'fulladdressunique_count_forssn_name_60',
#  'fulladdressunique_count_forssn_fulladdress_1',
#  'fulladdressunique_count_forssn_fulladdress_3',
#  'fulladdressunique_count_forssn_fulladdress_7',
#  'fulladdressunique_count_forssn_fulladdress_14',
#  'fulladdressunique_count_forssn_fulladdress_30',
#  'fulladdressunique_count_forssn_fulladdress_60',
#  'fulladdressunique_count_forssn_name_dob_1',
#  'fulladdressunique_count_forssn_name_dob_3',
#  'fulladdressunique_count_forssn_name_dob_7',
#  'fulladdressunique_count_forssn_name_dob_14',
#  'fulladdressunique_count_forssn_name_dob_30',
#  'fulladdressunique_count_forssn_name_dob_60',
#  'fulladdressunique_count_forssn_name_fulladdress_1',
#  'fulladdressunique_count_forssn_name_fulladdress_3',
#  'fulladdressunique_count_forssn_name_fulladdress_7',
#  'fulladdressunique_count_forssn_name_fulladdress_14',
#  'fulladdressunique_count_forssn_name_fulladdress_30',
#  'fulladdressunique_count_forssn_name_fulladdress_60',
#  'name_dobunique_count_forssn_1',
#  'name_dobunique_count_forssn_3',
#  'name_dobunique_count_forssn_7',
#  'name_dobunique_count_forssn_14',
#  'name_dobunique_count_forssn_30',
#  'name_dobunique_count_forssn_60',
#  'name_dobunique_count_forfulladdress_1',
#  'name_dobunique_count_forfulladdress_3',
#  'name_dobunique_count_forfulladdress_7',
#  'name_dobunique_count_forfulladdress_14',
#  'name_dobunique_count_forfulladdress_30',
#  'name_dobunique_count_forfulladdress_60',
#  'name_dobunique_count_forname_fulladdress_1',
#  'name_dobunique_count_forname_fulladdress_3',
#  'name_dobunique_count_forname_fulladdress_7',
#  'name_dobunique_count_forname_fulladdress_14',
#  'name_dobunique_count_forname_fulladdress_30',
#  'name_dobunique_count_forname_fulladdress_60',
#  'name_dobunique_count_forfulladdress_dob_1',
#  'name_dobunique_count_forfulladdress_dob_3',
#  'name_dobunique_count_forfulladdress_dob_7',
#  'name_dobunique_count_forfulladdress_dob_14',
#  'name_dobunique_count_forfulladdress_dob_30',
#  'name_dobunique_count_forfulladdress_dob_60',
#  'name_dobunique_count_fordob_homephone_1',
#  'name_dobunique_count_fordob_homephone_3',
#  'name_dobunique_count_fordob_homephone_7',
#  'name_dobunique_count_fordob_homephone_14',
#  'name_dobunique_count_fordob_homephone_30',
#  'name_dobunique_count_fordob_homephone_60',
#  'name_dobunique_count_forssn_lastname_1',
#  'name_dobunique_count_forssn_lastname_3',
#  'name_dobunique_count_forssn_lastname_7',
#  'name_dobunique_count_forssn_lastname_14',
#  'name_dobunique_count_forssn_lastname_30',
#  'name_dobunique_count_forssn_lastname_60',
#  'name_dobunique_count_forssn_zip5_1',
#  'name_dobunique_count_forssn_zip5_3',
#  'name_dobunique_count_forssn_zip5_7',
#  'name_dobunique_count_forssn_zip5_14',
#  'name_dobunique_count_forssn_zip5_30',
#  'name_dobunique_count_forssn_zip5_60',
#  'name_dobunique_count_forssn_name_1',
#  'name_dobunique_count_forssn_name_3',
#  'name_dobunique_count_forssn_name_7',
#  'name_dobunique_count_forssn_name_14',
#  'name_dobunique_count_forssn_name_30',
#  'name_dobunique_count_forssn_name_60',
#  'name_dobunique_count_forssn_fulladdress_1',
#  'name_dobunique_count_forssn_fulladdress_3',
#  'name_dobunique_count_forssn_fulladdress_7',
#  'name_dobunique_count_forssn_fulladdress_14',
#  'name_dobunique_count_forssn_fulladdress_30',
#  'name_dobunique_count_forssn_fulladdress_60',
#  'name_dobunique_count_forssn_name_dob_1',
#  'name_dobunique_count_forssn_name_dob_3',
#  'name_dobunique_count_forssn_name_dob_7',
#  'name_dobunique_count_forssn_name_dob_14',
#  'name_dobunique_count_forssn_name_dob_30',
#  'name_dobunique_count_forssn_name_dob_60',
#  'name_dobunique_count_forssn_name_fulladdress_1',
#  'name_dobunique_count_forssn_name_fulladdress_3',
#  'name_dobunique_count_forssn_name_fulladdress_7',
#  'name_dobunique_count_forssn_name_fulladdress_14',
#  'name_dobunique_count_forssn_name_fulladdress_30',
#  'name_dobunique_count_forssn_name_fulladdress_60',
#  'name_fulladdressunique_count_forssn_1',
#  'name_fulladdressunique_count_forssn_3',
#  'name_fulladdressunique_count_forssn_7',
#  'name_fulladdressunique_count_forssn_14',
#  'name_fulladdressunique_count_forssn_30',
#  'name_fulladdressunique_count_forssn_60',
#  'name_fulladdressunique_count_forfulladdress_1',
#  'name_fulladdressunique_count_forfulladdress_3',
#  'name_fulladdressunique_count_forfulladdress_7',
#  'name_fulladdressunique_count_forfulladdress_14',
#  'name_fulladdressunique_count_forfulladdress_30',
#  'name_fulladdressunique_count_forfulladdress_60',
#  'name_fulladdressunique_count_forname_dob_1',
#  'name_fulladdressunique_count_forname_dob_3',
#  'name_fulladdressunique_count_forname_dob_7',
#  'name_fulladdressunique_count_forname_dob_14',
#  'name_fulladdressunique_count_forname_dob_30',
#  'name_fulladdressunique_count_forname_dob_60',
#  'name_fulladdressunique_count_forfulladdress_dob_1',
#  'name_fulladdressunique_count_forfulladdress_dob_3',
#  'name_fulladdressunique_count_forfulladdress_dob_7',
#  'name_fulladdressunique_count_forfulladdress_dob_14',
#  'name_fulladdressunique_count_forfulladdress_dob_30',
#  'name_fulladdressunique_count_forfulladdress_dob_60',
#  'name_fulladdressunique_count_fordob_homephone_1',
#  'name_fulladdressunique_count_fordob_homephone_3',
#  'name_fulladdressunique_count_fordob_homephone_7',
#  'name_fulladdressunique_count_fordob_homephone_14',
#  'name_fulladdressunique_count_fordob_homephone_30',
#  'name_fulladdressunique_count_fordob_homephone_60',
#  'name_fulladdressunique_count_forssn_lastname_1',
#  'name_fulladdressunique_count_forssn_lastname_3',
#  'name_fulladdressunique_count_forssn_lastname_7',
#  'name_fulladdressunique_count_forssn_lastname_14',
#  'name_fulladdressunique_count_forssn_lastname_30',
#  'name_fulladdressunique_count_forssn_lastname_60',
#  'name_fulladdressunique_count_forssn_zip5_1',
#  'name_fulladdressunique_count_forssn_zip5_3',
#  'name_fulladdressunique_count_forssn_zip5_7',
#  'name_fulladdressunique_count_forssn_zip5_14',
#  'name_fulladdressunique_count_forssn_zip5_30',
#  'name_fulladdressunique_count_forssn_zip5_60',
#  'name_fulladdressunique_count_forssn_name_1',
#  'name_fulladdressunique_count_forssn_name_3',
#  'name_fulladdressunique_count_forssn_name_7',
#  'name_fulladdressunique_count_forssn_name_14',
#  'name_fulladdressunique_count_forssn_name_30',
#  'name_fulladdressunique_count_forssn_name_60',
#  'name_fulladdressunique_count_forssn_fulladdress_1',
#  'name_fulladdressunique_count_forssn_fulladdress_3',
#  'name_fulladdressunique_count_forssn_fulladdress_7',
#  'name_fulladdressunique_count_forssn_fulladdress_14',
#  'name_fulladdressunique_count_forssn_fulladdress_30',
#  'name_fulladdressunique_count_forssn_fulladdress_60',
#  'name_fulladdressunique_count_forssn_name_dob_1',
#  'name_fulladdressunique_count_forssn_name_dob_3',
#  'name_fulladdressunique_count_forssn_name_dob_7',
#  'name_fulladdressunique_count_forssn_name_dob_14',
#  'name_fulladdressunique_count_forssn_name_dob_30',
#  'name_fulladdressunique_count_forssn_name_dob_60',
#  'name_fulladdressunique_count_forssn_name_fulladdress_1',
#  'name_fulladdressunique_count_forssn_name_fulladdress_3',
#  'name_fulladdressunique_count_forssn_name_fulladdress_7',
#  'name_fulladdressunique_count_forssn_name_fulladdress_14',
#  'name_fulladdressunique_count_forssn_name_fulladdress_30',
#  'name_fulladdressunique_count_forssn_name_fulladdress_60',
#  'fulladdress_dobunique_count_forssn_1',
#  'fulladdress_dobunique_count_forssn_3',
#  'fulladdress_dobunique_count_forssn_7',
#  'fulladdress_dobunique_count_forssn_14',
#  'fulladdress_dobunique_count_forssn_30',
#  'fulladdress_dobunique_count_forssn_60',
#  'fulladdress_dobunique_count_forfulladdress_1',
#  'fulladdress_dobunique_count_forfulladdress_3',
#  'fulladdress_dobunique_count_forfulladdress_7',
#  'fulladdress_dobunique_count_forfulladdress_14',
#  'fulladdress_dobunique_count_forfulladdress_30',
#  'fulladdress_dobunique_count_forfulladdress_60',
#  'fulladdress_dobunique_count_forname_dob_1',
#  'fulladdress_dobunique_count_forname_dob_3',
#  'fulladdress_dobunique_count_forname_dob_7',
#  'fulladdress_dobunique_count_forname_dob_14',
#  'fulladdress_dobunique_count_forname_dob_30',
#  'fulladdress_dobunique_count_forname_dob_60',
#  'fulladdress_dobunique_count_forname_fulladdress_1',
#  'fulladdress_dobunique_count_forname_fulladdress_3',
#  'fulladdress_dobunique_count_forname_fulladdress_7',
#  'fulladdress_dobunique_count_forname_fulladdress_14',
#  'fulladdress_dobunique_count_forname_fulladdress_30',
#  'fulladdress_dobunique_count_forname_fulladdress_60',
#  'fulladdress_dobunique_count_fordob_homephone_1',
#  'fulladdress_dobunique_count_fordob_homephone_3',
#  'fulladdress_dobunique_count_fordob_homephone_7',
#  'fulladdress_dobunique_count_fordob_homephone_14',
#  'fulladdress_dobunique_count_fordob_homephone_30',
#  'fulladdress_dobunique_count_fordob_homephone_60',
#  'fulladdress_dobunique_count_forssn_lastname_1',
#  'fulladdress_dobunique_count_forssn_lastname_3',
#  'fulladdress_dobunique_count_forssn_lastname_7',
#  'fulladdress_dobunique_count_forssn_lastname_14',
#  'fulladdress_dobunique_count_forssn_lastname_30',
#  'fulladdress_dobunique_count_forssn_lastname_60',
#  'fulladdress_dobunique_count_forssn_zip5_1',
#  'fulladdress_dobunique_count_forssn_zip5_3',
#  'fulladdress_dobunique_count_forssn_zip5_7',
#  'fulladdress_dobunique_count_forssn_zip5_14',
#  'fulladdress_dobunique_count_forssn_zip5_30',
#  'fulladdress_dobunique_count_forssn_zip5_60',
#  'fulladdress_dobunique_count_forssn_name_1',
#  'fulladdress_dobunique_count_forssn_name_3',
#  'fulladdress_dobunique_count_forssn_name_7',
#  'fulladdress_dobunique_count_forssn_name_14',
#  'fulladdress_dobunique_count_forssn_name_30',
#  'fulladdress_dobunique_count_forssn_name_60',
#  'fulladdress_dobunique_count_forssn_fulladdress_1',
#  'fulladdress_dobunique_count_forssn_fulladdress_3',
#  'fulladdress_dobunique_count_forssn_fulladdress_7',
#  'fulladdress_dobunique_count_forssn_fulladdress_14',
#  'fulladdress_dobunique_count_forssn_fulladdress_30',
#  'fulladdress_dobunique_count_forssn_fulladdress_60',
#  'fulladdress_dobunique_count_forssn_name_dob_1',
#  'fulladdress_dobunique_count_forssn_name_dob_3',
#  ...]
